# %% [markdown]
# # 데이터 크롤링

# %%
# %matplotlib inline
#주피터노트북에서 라인 아래에 보여지도록 설정

# %config InlineBackend.figure_formats = {'png','retina'} 
#png 이미지 압축기술설정, retina 그래프 해상도 2배 높히기

# %% [markdown]
# ------

# %%
#get하여 html가져오기

import requests

r = requests.get('https://www.google.co.kr/search?q=KB금융')
r.text[:1000]
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><link href="/images/branding/product/ico/googleg_lodp.ico" rel="shortcut icon"><title>KB금융 - Google 검색</title><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important} </style><style>.star{float:left;margin-top:1px;overflow:hidden}.ybhkme{font-size:11px}.j{width:34em}body,td,div,.p,a{font-family:arial,sans-serif;tap-highligh'

# %%
# 구글 검색결과 갯수 가져오기

import requests
from bs4 import BeautifulSoup
r = requests.get("https://www.google.co.kr/search?q=검색")

soup = BeautifulSoup(r.content, 'lxml')
res_stat = soup.find(id='resultStats').text

print(res_stat)
# Out:
# 검색결과 약 17,400,000개

# %% [markdown]
# ---

# %%
#삼성전자 주식정보 가져오기

code = '005930'
url = 'http://companyinfo.stock.naver.com/v1/company/c1010001.aspx?cmp_cd='+code

r = requests.get(url)
soup = BeautifulSoup(r.text,"lxml")
td = soup.find('td', {'class':'cmp-table-cell td0101'})
td
# Out:
# <td class="cmp-table-cell td0101">
# <dl>
# <dt>
# <span class="name">삼성전자</span>
# <a class="cEm" href="http://www.samsung.com" target="comPage" title="[홈페이지] www.samsung.com"><img align="absmiddle" hspace="3" src="/images/icon_home.gif"/></a>
# <a class="cEm" title="[대표전화] 031-200-1114
# [주식담당] 02-2255-8126"><img align="absmiddle" hspace="1" src="/images/icon_tel.gif"/></a>
# <b class="num">005930</b>
# </dt>
# <dt class="line-left">Samsung Electronics</dt>
# <dt class="line-left">KOSPI : 전기전자</dt>
# <dt class="line-left">WICS : 반도체와반도체장비</dt>
# </dl>
# </td>

# %%
td.find('span',{"class":'name'}).text
# Out:
# '삼성전자'

# %%
anchors = td.find_all('a', {'class':'cEm'})
print(anchors[0]['href'])
print(anchors[1]['title'])
# Out:
# http://www.samsung.com
# [주식담당] 02-2255-8126

# %%
dts = td.find_all('dt',{"class":"line-left"})
print(dts[0].text)
print(dts[1].text)
print(dts[2].text)
# Out:
# Samsung Electronics
# KOSPI : 전기전자
# WICS : 반도체와반도체장비

# %% [markdown]
# ---

# %%
# 네이버 실시간 급상승 검색어 크롤링
import re
import requests

html_text= requests.get('http://naver.com').text
re.findall('<span class="ah_k">(.*?)</span>', html_text)[:20]
# Out:
# ['진경산수화',
#  '아파트투유',
#  '혈우병',
#  '케빈',
#  '왠지',
#  '픽토그램',
#  '수요미식회 맥주',
#  '이사강',
#  '도깨비 김서방',
#  '김상민',
#  '김경란',
#  '정선',
#  '2018 워터밤',
#  'ipa 맥주',
#  '아파트투유 우리은행',
#  '포항지진',
#  '사모형 펀드',
#  '배그 점검',
#  '국민은행 주택청약',
#  '손은서']

# %%
# JSON 데이터 받기 - 네이버 실시간 검색어 순위
import json, requests
from pandas.io.json import json_normalize

r = requests.get('http://rank.search.naver.com/rank.js')
json_normalize(json.loads(r.text), ['data','data'])
json.loads(r.text)
# Out:
# {'data': [{'category': 'general',
#    'data': [{'change': '+',
#      'cvalue': 842,
#      'delta': 0,
#      'keyword': '유보화',
#      'rank': 1,
#      'ratio': '.',
#      'score': 636,
#      'tvalue': 64.78869},
#     {'change': '+',
#      'cvalue': 294,
#      'delta': 0,
#      'keyword': '거기가 어딘데',
#      'rank': 2,
#      'ratio': '.',
#      'score': 252,
#      'tvalue': 20.01178},
#     {'change': '+',
#      'cvalue': 210,
#      'delta': 0,
#      'keyword': '프랑스 이탈리아',
#      'rank': 3,
#      'ratio': 'new',
#      'score': 270,
#      'tvalue': 15.39646},
#     {'change': '+',
#      'cvalue': 224,
#      'delta': 1,
#      'keyword': '김교순',
#      'rank': 4,
#      'ratio': '-',
#      'score': 441,
#      'tvalue': 14.4381},
#     {'change': '+',
#      'cvalue': 116,
#      'delta': 1,
#      'keyword': '나혼자산다',
#      'rank': 5,
#      'ratio': '-',
#      'score': 63,
#      'tvalue': 4.61451},
#     {'change': '+',
#      'cvalue': 65,
#      'delta': 1,
#      'keyword': '진서연',
#      'rank': 6,
#      'ratio': '-',
#      'score': 72,
#      'tvalue': 4.5801},
#     {'change': '+',
#      'cvalue': 128,
#      'delta': 1,
#      'keyword': '비긴어게인2',
#      'rank': 7,
#      'ratio': '-',
#      'score': 51,
#      'tvalue': 3.8852},
#     {'change': '+',
#      'cvalue': 62,
#      'delta': 1,
#      'keyword': '영화순위',
#      'rank': 8,
#      'ratio': '-',
#      'score': 63,
#      'tvalue': 3.52623},
#     {'change': '+',
#      'cvalue': 95,
#      'delta': 1,
#      'keyword': '롯데시네마',
#      'rank': 9,
#      'ratio': '-',
#      'score': 36,
#      'tvalue': 3.33985},
#     {'change': '+',
#      'cvalue': 52,
#      'delta': 1,
#      'keyword': '선풍기',
#      'rank': 10,
#      'ratio': '-',
#      'score': 54,
#      'tvalue': 3.14377},
#     {'change': '+',
#      'cvalue': 70,
#      'delta': 0,
#      'keyword': '피파4',
#      'rank': 11,
#      'ratio': '.',
#      'score': 54,
#      'tvalue': 2.92727},
#     {'change': '+',
#      'cvalue': 67,
#      'delta': 2,
#      'keyword': '더콜',
#      'rank': 12,
#      'ratio': '-',
#      'score': 84,
#      'tvalue': 2.91143},
#     {'change': '+',
#      'cvalue': 55,
#      'delta': 0,
#      'keyword': '기성용',
#      'rank': 13,
#      'ratio': 'new',
#      'score': 105,
#      'tvalue': 2.72912},
#     {'change': '+',
#      'cvalue': 196,
#      'delta': 2,
#      'keyword': '영화',
#      'rank': 14,
#      'ratio': '-',
#      'score': 21,
#      'tvalue': 2.70001},
#     {'change': '+',
#      'cvalue': 100,
#      'delta': 0,
#      'keyword': '스케치',
#      'rank': 15,
#      'ratio': '.',
#      'score': 39,
#      'tvalue': 2.51076},
#     {'change': '+',
#      'cvalue': 147,
#      'delta': 2,
#      'keyword': '하트시그널 시즌2',
#      'rank': 16,
#      'ratio': '-',
#      'score': 33,
#      'tvalue': 2.45242},
#     {'change': '+',
#      'cvalue': 73,
#      'delta': 4,
#      'keyword': '카트라이더',
#      'rank': 17,
#      'ratio': '-',
#      'score': 48,
#      'tvalue': 2.36686},
#     {'change': '+',
#      'cvalue': 65,
#      'delta': 1,
#      'keyword': '테일즈런너',
#      'rank': 18,
#      'ratio': '+',
#      'score': 60,
#      'tvalue': 2.24781},
#     {'change': '+',
#      'cvalue': 126,
#      'delta': 0,
#      'keyword': '리그오브레전드',
#      'rank': 19,
#      'ratio': 'new',
#      'score': 30,
#      'tvalue': 2.18309},
#     {'change': '+',
#      'cvalue': 91,
#      'delta': 2,
#      'keyword': '현대자동차',
#      'rank': 20,
#      'ratio': '-',
#      'score': 27,
#      'tvalue': 2.14886}]}],
#  'et': '2018-06-02T12:48:00+0900',
#  'st': '2018-06-02T12:38:00+0900',
#  'ts': '2018-06-02T13:02:00+0900'}

# %%
# time stamp
r = requests.get('http://rank.search.naver.com/rank.js')
json.loads(r.text)['ts']
# Out:
# '2018-05-31T12:57:00+0900'

# %% [markdown]
# ---
# ### 한글인코딩 전화번호부 사이트
# - 한국 사이트중 euc-kr 인코딩이 되어있어 재처리 해야하는 경우

# %%
# searchWord:%C8%DE%C0%CF%C1%F8%B7%E1
# x:37.5640907
# y:126.9979403
# dong:
# city:%BC%AD%BF%EF
# gu:%C1%DF%B1%B8
# addr4:
# addr:%BC%AD%BF%EF+%C1%DF%B1%B8

from urllib.parse import quote, unquote

# 이걸 euc-kr인코딩으로 바꿔주면 '휴일진료'라는 글자로 바뀐다.
u = '%C8%DE%C0%CF%C1%F8%B7%E1' 
print (unquote(u, encoding='euc-kr'))

u = '%BC%AD%BF%EF'
print (unquote(u, encoding='euc-kr'))

u = '%BC%AD%BF%EF+%C1%DF%B1%B8'
print (unquote(u, encoding='euc-kr'))
# Out:
# 휴일진료
# 서울
# 서울+중구

# %%
#str(유니코드) -> bytes(EUC-KR) -> URL Quot

b = '휴일진료'.encode('euc-kr')
print( type(b) )
print( quote(b) )
# Out:
# <class 'bytes'>
# %C8%DE%C0%CF%C1%F8%B7%E1

# %%
# URL Quot (EUC-KR) -> str(유니코드)

u = '%C8%DE%C0%CF%C1%F8%B7%E1'
s = unquote(u, encoding='euc-kr')
print(type(s))
print(s)
# Out:
# <class 'str'>
# 휴일진료

# %%
# 해결책 ------str.encode('euc-kr')--------------
import requests
import time
url = 'http://www.isuperpage.co.kr/search.asp'


data = {
    'searchWord':'휴일진료'.encode('euc-kr'),
    'dong':''.encode('euc-kr'),
    'city':'서울'.encode('euc-kr'),
    'gu':'중구'.encode('euc-kr')
}

r = requests.post(url, data=data)
r.text[:1000]
# Out:
# '\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n<meta charset="euc-kr">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n<title>:: 대한민국 모든 전화번호 검색은 한국전화번호부 ::</title>\r\n<link rel="stylesheet" type=\'text/css\' href="/css3/base_n_n.css"/>\r\n<link href="/css3/dcaccordion.css" rel="stylesheet" type="text/css" />\r\n<link href="/jqy/jquery-ui.css" rel="stylesheet" type="text/css" />\r\n<script type="text/javascript" src="/jqy/jquery-1.11.2.min.js"></script>\r\n<script src="/jqy/jquery-ui-1.10.3.custom.min.js"></script>\r\n<script src="/jqy/jquery.ba-dotimeout.min.js"></script>\r\n<script src="/jqy/common_web.js"></script>\r\n<script src="/jqy/placeholders.min.js"></script>\r\n\r\n  \r\n\r\n\r\n<script language="javascript">\r\n\r\n\r\n$(function() {\r\n\t$("img.lmimg").mouseover(function() {\r\n\t\r\n\t\t$(this).attr("src",$(this).attr("src").replace("off","on"));\r\n\t});\r\n  $("img.lmimg").mouseout(function() {\r\n        $(this).css("display","");\r\n\t\t$(this).attr("src",$(this).attr("src").replace("on","off"));\r\n\t});\t\r\n\t\r\n});\r\n\r'

# %%
from bs4 import  BeautifulSoup
soup = BeautifulSoup(r.text, 'lxml-xml')
search_result = soup.find('div', {'id':'search_result'})
print(soup)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="euc-kr">
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>:: 대한민국 모든 전화번호 검색은 한국전화번호부 ::</title>
# <link href="/css3/base_n_n.css" rel="stylesheet" type="text/css"/>
# <link href="/css3/dcaccordion.css" rel="stylesheet" type="text/css"/>
# <link href="/jqy/jquery-ui.css" rel="stylesheet" type="text/css"/>
# <script src="/jqy/jquery-1.11.2.min.js" type="text/javascript"/>
# <script src="/jqy/jquery-ui-1.10.3.custom.min.js"/>
# <script src="/jqy/jquery.ba-dotimeout.min.js"/>
# <script src="/jqy/common_web.js"/>
# <script src="/jqy/placeholders.min.js"/>
# <script language="javascript">
#
#
# $(function() {
# 	$("img.lmimg").mouseover(function() {
#
# 		$(this).attr("src",$(this).attr("src").replace("off","on"));
# 	});
#   $("img.lmimg").mouseout(function() {
#         $(this).css("display","");
# 		$(this).attr("src",$(this).attr("src").replace("on","off"));
# 	});
#
# });
#
# function setmCookie(name, value)
# {
#
# 		$.cookie(name, value, {expires:30});
# 		return;
#
# }
#
#
# function getmCookie(name)
# {
# 	var cookie_val = $.cookie(name);
# 	if ( typeof (cookie_val) == "undefined" || cookie_val == null ) return [];
#
# 	return cookie_val;
# }
#
# function gomain() {
# setmCookie("cur_page","1");
# location.href="/";
#
# }
#
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-63121449-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# <style type="text/css">
# #content_wrap {
# 	clear:left;
# 	width:100%;
# 	margin:0 auto;
# 	height:auto;
# }
# .lboxs1 {
# 	padding-top:0px;
# }
# .lboxs1 li, .exgo {
# 	color:#000000;
# 	font-size: 12px !important;
# }
# .lboxs1 li a.exgo:hover, .lboxs1 li a.exgo:active {
# 	color:#FBE901 !important;
# }
# .gap {
# 	height: 12px;
# 	margin: 3px 14px;
# 	border-right: 1px solid #ffffff;
# 	border-left: 1px solid #CCCCCC;
# }
# </style>
# </meta>
# <body>
# <style type="text/css">
#
# #gnb, #gnb .gRight1 { width:1080px; }
# #wrap_search {
# 	width:100%; margin:0 auto; border-bottom:#747474 solid 1px; height:109px;
# }
# #wrap_search_in {
# 	 width:1080px; margin:0 auto; height:109px; line-height:109px;
# }
# .srcaddout { float:left;height:109px; line-height:109px;margin-right:10px; position:relative; }
# #stitimg { float:left; width:190px; padding:44px 0 0 0; text-align:left; }
# #topinfo { float:left; width:377px;  visibility:visible; display:inline-block; }
#
# .poi_red {
# 	font-size:14px;
# 	color:#FF0000;
# }
#
# .js_wrap {
# 	width:210px;
# 	position:absolute;
# 	top:77px;
# 	left:0;
# 	border:1px solid #666;
# 	background:#fff;
# 	z-index:1000000;
# }
# .findtxt_fixed .js_wrap {
# 	width:330px;
# 	position:absolute;
# 	top:25px;
# 	left:4px;
# 	border:1px solid #666;
# 	background:#fff;
# 	z-index:1000;
# }
# .js_wrap .js_body, .js_wrap #js_body_sword {
# 	clear:both;
# 	background:#fff;
# 	font-size:12px;
# 	color: #848484;
# 	position:relative;
#
# 	line-height: 12px;
# 	padding: 8px 0 6px;
# 	text-align:left;
# 	background:#fff;
# }
# .js_wrap .js_body dl dt {
#
# 	padding: 7px 0px 7px 11px;
# }
# .js_wrap .js_body dl dd {
#
# 	padding: 7px 0px 7px 11px;
# }
# .js_wrap .js_body dl dt:hover {
# 	background-color:#efefef;
# }
# .js_wrap .js_body dl dd:hover {
# 	background-color:#efefef;
# }
# .js_wrap .js_body ul li.guide {
# 	margin-bottom: -6px;
# 	margin-top: 7px;
# }
# .js_wrap .js_body ul li {
# 	padding: 7px 0 7px 11px;
# }
# .findtxt_fixed .js_wrap .js_body ul li {
# 	font-size: 14px;
# 	padding: 9px 0 9px 11px;
# }
# .js_wrap .js_body li:hover {
# 	background-color:#efefef;
# }
# .js_wrap .js_body .selected {
# 	background-color:#efefef;
# }
# ul.js_body li {
# 	font-size: 14px;
# 	padding: 9px 0 9px 11px;
# }
# ul.js_body li:hover {
# 	background-color:#efefef;
# }
# ul.js_body .selected {
# 	background-color:#efefef;
# }
# .js_wrap .guide {
# 	border-top:1px solid #E1E1E1;
# 	background:#F7F7F7;
# 	padding:7px 7px 7px 11px;
# 	zoom:1;
# 	letter-spacing:-1px;
# 	color: #848484;
# 	font-size: 11px;
# 	position: relative;
# 	text-align:left;
# }
# .js_wrap .guide:after {
# 	content:".";
# 	display:block;
# 	height:0;
# 	clear:both;
# 	visibility:hidden;
# }
# .js_wrap .guide .btn_off {
# 	color: #777;
# 	display: block;
# 	position: absolute;
# 	top: 7px;
# 	right: 8px;
# 	font-size: 11px;
# }
# .ui-menu .ui-menu-item a {
# 	text-align:left !important;
# }
# .srcwrdout { float:right; padding-top:41px;}
# .srcwrdin { border:3px #FBE901 solid;height:26px; }
# .js_inputbox { width:172px; height:26px; line-height:26px; border:3px #FBE901 solid;background: url(/images/search_dr.png) 170px center #FFFFFF no-repeat;padding:0 8px 0 7px; color:#848484; }
# #search_word { width:266px; height:26px; line-height:26px; padding:0; font-size:13px; color:#848484; padding:0 0 0 7px; margin:0; }
#
# #query_submit {  height:26px; cursor:pointer;  }
# #auto-area-id-cookie-0 { color: #0066FF; font-weight:500;  }
# </style>
# <div id="wrap">
# <!-- s:header -->
# <div id="header">
# <div id="gnb">
# <div class="gRight1" style="position:relative;">
# <ul class="lboxs1" style="position:absolute; right:0;">
# <li> <a class="exgo" href="javascript:gomain();"> 처음으로 </a> </li>
# <li class="gap"/>
# <li><a class="exgo" href="/members/login.asp?url=/search.asp">로그인</a></li><li class="gap"/>
# <li> <a class="exgo" href="/bbs/ceo/regi_info.asp">전화번호부 등록/수정</a> </li>
# <li class="gap"/>
# <li> <a class="exgo" href="/bbs/ktdc/premium_ad_info.asp"> 사업 안내 </a> </li>
# <li class="gap"/>
# <li> <a class="exgo" href="/myzone/index.asp"> 마이 페이지 </a> </li>
# <li class="gap"/>
# <li> <a class="exgo" href="/bbs/notice/list.asp"> 고객 센터 </a> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div id="wrap_search">
# <div id="wrap_search_in">
# <div id="stitimg"><a href="javascript:gomain();"><img alt="메인으로" src="/image/logo.png" title="메인으로"/></a>
# <div id="topinfo"/>
# <div class="srcaddout">
# <input class="i1 js_inputbox" id="Autocomplete_addr_a" type="text">1 value="" &gt;
#       <p id="area_more" style="display:none;">더보기</p>
# <div class="js_wrap" id="Autocomplete_box_dong" style="display:none;">
# <div class="js_body" id="js_body_dong"> </div>
# <div class="guide"> 원하는 지역명을 입력해주세요 <a class="btn_off" href="#" id="JsUseN">끄기</a> </div>
# </div>
# </input>
# <div class="srcwrdout">
# <div class="srcwrdin">
# <input id="search_word" type="text" value="휴일진료">2 placeholder="업종, 상호, 전화번호 검색"&gt;
#         <img id="query_submit" src="/image/sub_search2.png">
# <div class="js_wrap" id="Autocomplete_box_sword" style="display:none;">
# <div class="js_body" id="js_body_sword"> </div>
# </div>
# </img>
# </input>
# <input id="autoSMode" type="hidden" value="0"/>
# <input id="autoAddrMode" type="hidden" value="0"/>
# <form id="searchForm" method="post" name="searchForm">
# <input id="searchWord" name="searchWord" type="hidden" value="휴일진료"/>
# <input id="x" name="x" type="hidden" value=""/>
# <input id="y" name="y" type="hidden" value=""/>
# <input id="dong" name="dong" type="hidden"/>
# <input id="city" name="city" type="hidden"/>
# <input id="gu" name="gu" type="hidden"/>
# <input id="addr4" name="addr4" type="hidden"/>
# <input id="addr" name="addr" type="hidden" value=""/>
# <input id="currentPage" type="hidden" value=""/>
# <input id="rowsPerPage" type="hidden" value="10"/>
# <input id="blockSize" type="hidden" value="10"/>
# </form>
# </div>
# </div>
# <style type="text/css">
#
# #contentarea {
#
# 	width:1080px;
# 	height:100%;
#
# }
#
# #prcenterarea {
#
# 	float:left;
# 	width:689px;
# 	padding:0;
# 	text-align:left;
# 	height:auto;
#
#
# 	border-right:#CCCCCC solid 1px;
# 	border-bottom:#CCCCCC solid 1px;
#
# }
#
# #prrightarea {
#
# 	float:right;
# 	width:330px;
# 	height:auto;
# 	margin:0 auto;
#
# }
# .stftgulim { font-family: "굴림",gulim,helvetica,sans-serif ; letter-spacing:0; }
# #premiumarea {  padding:26px 26px 26px 0; height:285px; }
#
# #centerarea {
# 	float:left;
# 	width:689px;
#
# 	border-right:#CCCCCC solid 1px;
# 	padding:0;
# 	text-align:left;
# 	min-height: 1300px;
# }
#
#
#
# #rightarea {
# 	float:right;
# 	width:390px;
# 	height:100%;
#
#
#
# }
#
#
# .stitwrap {
# 	clear:left;
# 	text-align:left;
# 	padding:10px 0 1px 0;
# 	position:relative;
#
# }
#
#
#
# .stit {
#
# 	color:#000000;
# 	font-size:13px;
# 	font-family: "굴림",gulim,helvetica,sans-serif ;
# 	font-weight:600;
# 	letter-spacing:0;
# }
#
#
# .stit2 {
# 	clear:left;
# 	text-align:left;
# 	padding:0 0 10px 0;
# 	color:#000000;
# 	font-size:12px;
# 	font-family: "굴림",gulim,helvetica,sans-serif ;
# 	letter-spacing:0;
# }
#
# .stit2 .scword {
# 	color:#eb0c00;
#
# 	font-size:12px;
# 	font-family: "굴림",gulim,helvetica,sans-serif ;
# 	font-weight:600;
# 	letter-spacing:0;
# }
# .tablecenter th, .tablecenter td {
# 	text-align:center;
# }
# .dl-horizontal2 {
# 	clear:left;
# }
# .dl-horizontal2 dt {
# 	width:65%;
# }
# .dl-horizontal2 dt, .dl-horizontal2 dd {
# 	float:left;
# 	font-size:12px;
# }
# .answerlist li {
# 	padding:3px 0 3px 17px;
# 	clear:both;
# }
#
# .answerlist li.premiuarea {
# 	/*padding:10px 0 10px 30px;*/
# 	background-color:#fffef8!important;
# 	/*margin-right:20px;*/
# 	position:relative; left:-30px;padding:5px 0 5px 50px; width:669px;
#
# }
#
# .answerlist li.linegaps0 { background-color:#fffef8!important; height:55px; line-height:55px; position:relative; left:-30px; padding:0; width:719px!important; text-align:right; }
# .answerlist li.linegaps { background-color:#fffef8!important; height:1px; border-bottom:#e8e8e8 solid 1px; position:relative; left:-30px; padding:0; width:690px!important;}
# .answerlist li.linegaps2 { background-color:#fffef8!important; height:1px; border-bottom:#e8e8e8 solid 1px; position:relative; left:-30px; padding:0; width:690px!important;}
#
# .answerlist li.genarea {
#
# padding:12px 0 3px 0;
#
# margin-right:20px;
# }
#
#
# .answerlist li.genarea1 {
# padding: 3px 0 3px 0;
#
#
# }
#
#
#
# .answerlist li .l_tit {
# 	font-size:13px;
# 	color:#000;
# 	font-family: "굴림",gulim,helvetica,sans-serif ;
# 	text-decoration:underline;
# 	font-weight:600;
# 	letter-spacing:0;
#
# }
#
# .answerlist li.premiuarea .l_tit {
# 	font-size:13px;
# 	color:#00c;
# 	font-family: "굴림",gulim,helvetica,sans-serif ;
# 	font-weight:600;
# 	text-decoration:underline;
# 	letter-spacing:0;
# }
#
#
# .answerlist li .l_ser  {
# 	font-size:11px;
# 	padding-left:3px;
# 	font-family: "굴림",gulim,helvetica,sans-serif ;
# 	color:#7f7f7f;
# 	letter-spacing:0;
# }
#
# .answerlist li .tit_list, .tit_list {
#
# 	padding:0 0 0 35px;
# 	height:25px;
#
# }
#
#
# .answerlist li .l_cont , .l_cont  {
# 	font-size:12px;
# 	padding:0 0 0 35px;
# 	font-family: "굴림",gulim,helvetica,sans-serif ;
# 	height:25px;
# 	letter-spacing:0;
# }
# .answerlist li .l_cont .phone {
#
# 	padding-right: 10px;
# 	font-family: "굴림",gulim,helvetica,sans-serif ;
# 	letter-spacing:0;
# }
#
# .answerlist li .l_cont .phone2 {
# 	color: #218d44;
# 	padding: 0 10px 0 12px;
# 	font-family: "굴림",gulim,helvetica,sans-serif ;
# 	font-size:12px;
# 	letter-spacing:0;
#
# }
#
# .answerlist li .l_cont span {
# font-family: "굴림",gulim,helvetica,sans-serif ;
# font-size:12px;
# color:#000000;
# letter-spacing:0;
#
# }
#
# .sdivider-vertical {
# 	padding-left:10px;
# }
# .roada {
# 	font-size:11px;
# 	border:#CCCCCC solid 1px;
# 	padding:1px 3px;
# 	margin-left:10px;
# }
# .subtit {
# 	padding:25px 0 0 0;
# 	font-size:15px;
# 	color:#000000;
# 	font-weight:600;
#
# }
#
# .psubtit {
# 	padding:15px 0 0 0;
# 	font-size:14px;
# 	color:#000000;
#
#
# }
#
#
# .navs { text-align:center;  width:100%; margin: 0 auto; padding:25px 0 25px 0;  }
# .pagination {
# 	display: inline-block;
# 	margin: 20px;
# 	border-radius: 4px;
#
#
# }
# .pagination &gt; li {
# 	display: inline;
# }
# .pagination-sm &gt; li:first-child &gt; a, .pagination-sm &gt; li:first-child &gt; span {
# 	border-bottom-left-radius: 3px;
# 	border-top-left-radius: 3px;
# }
# .pagination &gt; li:first-child &gt; a, .pagination &gt; li:first-child &gt; span {
# 	margin-left: 0px;
# 	border-bottom-left-radius: 4px;
# 	border-top-left-radius: 4px;
# }
# .pagination-sm &gt; li &gt; a, .pagination-sm &gt; li &gt; span {
# 	padding: 5px 10px;
# 	font-size: 12px;
# }
# .pagination-sm &gt; li &gt; a.currentp {
# 	font-weight:600;
# 	color:#FF0000 !important;
# }
# .pagination &gt; li &gt; a, .pagination &gt; li &gt; span {
# 	position: relative;
# 	float: left;
# 	padding: 6px 12px;
# 	margin-left: -1px;
# 	line-height: 1.42857;
# 	text-decoration: none;
# 	background-color: #FFF;
# 	border: 1px solid #DDD;
# }
# .table-bordered {
# 	border-top: 1px solid #DDD;
# 	border-bottom: 1px solid #DDD;
# }
# .table {
# 	width: 100%;
# 	margin-bottom: 20px;
# }
# table {
# 	max-width: 100%;
# 	background-color: transparent;
# }
# table {
# 	border-collapse: collapse;
# 	border-spacing: 0px;
# }
# .table-bordered &gt; thead &gt; tr &gt; th, .table-bordered &gt; tbody &gt; tr &gt; th, .table-bordered &gt; tfoot &gt; tr &gt; th, .table-bordered &gt; thead &gt; tr &gt; td, .table-bordered &gt; tbody &gt; tr &gt; td, .table-bordered &gt; tfoot &gt; tr &gt; td {
#
#
#
#
#
#
# 	border-top: 1px solid #DDD;
# 	border-bottom: 1px solid #DDD;
# }
# .table thead &gt; tr &gt; th, .table tbody &gt; tr &gt; th, .table tfoot &gt; tr &gt; th, .table thead &gt; tr &gt; td, .table tbody &gt; tr &gt; td, .table tfoot &gt; tr &gt; td {
# 	padding: 8px;
# 	line-height: 1.42857;
# 	vertical-align: top;
# 	border-top: 1px solid #DDD;
# }
#
#
# </style>
# <style type="text/css">
#
# .dl-horizontal2 dt, .dl-horizontal2 dd {
#     float: left;
#     font-size: 12px;
# }
# .dl-horizontal2 dt {
#     width: 65%;
# }
# dt {
#     font-weight: bold;
# }
# dt, dd {
#     line-height: 1.42857;
# }
# .load { font-size:11px; padding:2px; border: #fae900 solid 1px; margin-left:0; background-color: #fae900;}
# .load2 { width:54px; height:16px; padding-left:12px;
#  }
# .maparea { width:330px; margin:0 30px 0 30px; position:relative; }
# .mapwrap, .mapwrap2 { width:360px; margin:0 auto;  text-align:left;font-family: '나눔고딕',nanum gothic,'맑은고딕',malgun gothic,'돋움',Dotum,Helvetica,sans-serif;  text-align:left; font-weight: 700; color: #1F1F1F; font-size:14px;  padding:25px 0 10px 0; }
# .mapwrap3 { width:300px; margin:0 auto;  text-align:left; font-family: '나눔고딕',nanum gothic,'맑은고딕',malgun gothic,'돋움',Dotum,Helvetica,sans-serif;  text-align:left; font-weight: 700; color: #1F1F1F; font-size:14px; padding:5px 0 0 30px; }
# #viewlagego { cursor:pointer;   }
# .mapifwrap {width:176px; height:121px; overflow:hidden; }
# .mapifwrap li {font-size:11px;}
# .maptit1 { color:#000000; font-weight:600; border-bottom: #fae900 solid 2px; padding:5px 0;margin:5px 0; font-size:15px;}
# .mphe1 { color:#000000;}
# /* Base Styles */
#
# .top_horimenu { width:100%;  margin:0 auto; border-bottom: #e8e8e8 solid 1px;  }
#
#
# .maptit {  padding:0 0 5px 15px; width:674px; margin:0 auto;  clear:both;  }
#
#
# #cssmenu &gt; ul,
# #cssmenu &gt; ul li,
# #cssmenu &gt; ul ul {
#   list-style: none;
#   margin: 0;
#   padding: 0;
#
# }
# #cssmenu &gt; ul {
#   position: relative;
#   z-index: 597;
#   float: left;
# }
# #cssmenu &gt; ul li {
#   float: left;
#   min-height: 1px;
#   line-height: 1.3em;
#   vertical-align: middle;
#   padding: 10px;
#
# }
# #cssmenu &gt; ul li.hover,
# #cssmenu &gt; ul li:hover {
#   z-index: 599;
#   cursor: default;
#
# }
#
# #cssmenu &gt; ul ul {
#
#
# }
#
# #cssmenu &gt; ul ul li {
#   float: none;
# }
#
# #cssmenu &gt; ul li:hover &gt; ul {
#   /*visibility: visible;*/
# }
#
# /* Align last drop down RTL */
# /* Theme Styles */
#
# #cssmenu &gt; ul a:link {
#   text-decoration: none;
# }
#
# #cssmenu &gt; ul a:active {
#   color: #ffa500;
#
# }
#
# #cssmenu li {
#   padding: 0;
#   color: #000;
# }
#
# #cssmenu {
# position:relative;
#
#   width:1080px;
#   margin:0 auto;
#   font-size: 14px;
#
# }
# #cssmenu #menu-button {
#   display: none;
# }
# #cssmenu &gt; ul {
#   padding: 0 5px;
#   display: block;
#   float: none;
#   zoom: 1;
# }
# #cssmenu &gt; ul:before {
#   content: '';
#   display: block;
# }
# #cssmenu &gt; ul:after {
#   content: '';
#   display: table;
#   clear: both;
# }
# #cssmenu &gt; ul &gt; li {
#   padding: 8px 7px;
# }
#
# .startli {padding: 8px 14px 8px 0!important;}
# .endli {padding: 8px 0 8px 14px!important;}
#
# #cssmenu &gt; ul &gt; li &gt; a,
# #cssmenu &gt; ul &gt; li &gt; a:link,
# #cssmenu &gt; ul &gt; li &gt; a:visited {
#
#   padding: 7px 0 7px 25px;
#   display: block;
#   font-size:13px;
#
# }
# #cssmenu &gt; ul &gt; li &gt; a:hover,
# #cssmenu &gt; ul &gt; li:hover &gt; a {
#
# }
# #cssmenu li li a {
#   color: #8b8b8b;
#   font-size: 14px;
# }
# #cssmenu li li a:hover {
#   color: #5c5c5c;
#   border-color: #5c5c5c;
# }
# #cssmenu ul ul {
#
#   visibility: hidden;
#   position: absolute;
#   top: 46px;
#   margin: 0 10px;
#   padding: 0 10px;
#   float: none;
#   background-color:#FFFFFF;
#   border-top: 1px solid #E8E8E8;
#   right: 0;
#   left: 0;
#
# }
# #cssmenu ul &gt; li &gt; ul &gt; li {
#  /* margin: 0 10px 0 10px;*/
#   position: relative;
#   padding: 0;
#   float: left;
# }
# #cssmenu ul &gt; li &gt; ul &gt; li &gt; a {
#   padding: 8px 15px 8px 15px;
#   display: block;
#   font-size:12px;
# }
# #cssmenu ul &gt; li &gt; ul &gt; li.has-sub &gt; a:before {
#   content: '';
#   position: absolute;
#   top: 18px;
#   right: 6px;
#   border: 5px solid transparent;
#   border-top: 5px solid #8b8b8b;
# }
# #cssmenu ul &gt; li &gt; ul &gt; li.has-sub &gt; a:hover:before {
#   border-top: 5px solid #5c5c5c;
# }
# #cssmenu ul ul ul {
#   width: 200px;
#   top: 100%;
#   border: 2px solid #1b9bff;
# }
# #cssmenu ul ul ul li {
#   float: none;
# }
# #menu-line {
#   position: absolute;
#   top: 42px;
#   left: 0;
#   height: 4px;
#   background: #FBE901;
#   -webkit-transition: all 0.25s ease-out;
#   -moz-transition: all 0.25s ease-out;
#   -ms-transition: all 0.25s ease-out;
#   -o-transition: all 0.25s ease-out;
#   transition: all 0.25s ease-out;
# }
# .in_accd li a { font-size:13px; }
#
#
# .prstit_i2 {
# 	clear:left;
# 	text-align:left;
#
# 	color: #32363e;
# 	font-size:25px;
#
# 	font-weight: 800;
# 	letter-spacing:-1px;
# 	height: 40px;
#
# }
#
#
# .prstit2 {
# 	clear:left;
# 	text-align:left;
#
#
# 	border-top: #e9e9e9 solid 1px;
# 	padding-top:12px;
# 	margin-top:17px;
# 	width:320px;
#
# }
# .prstit2_1 {color: #0000cc;
# 	font-size:13px;
#
# 	font-weight:600;
# 	text-decoration:underline;
# }
#
# .premi_dd { clear:left;    width: 638px;
#     height: 105px; border:#e7ebef solid 1px;
# 	background-color:#f9fafb;
# 	margin-left:20px;
#  }
# .premi_dd li { float:left;}
# .prddul {  padding:14px 24px 18px 24px; width:206px;  }
# .pdtul li { float:left; }
# .prddtit { clear:left; font-size:12px; text-align:center; color:#000000; font-weight:600; padding:6px 0 6px 0; border-bottom:#e9e9e9 solid 1px;border-top:#e9e9e9 solid 1px; background-color:#f7f7f7; margin-top:25px;  }
# .pd_tit  { float:left; width:83px;padding:5px 0 5px 22px; color:#000000; font-weight:600; font-size:12px; 	font-family: "굴림",gulim,helvetica,sans-serif;letter-spacing:0; }
# .pd_cont { float:left; padding:5px 0 5px 22px; font-size:12px;border-left:#e9e9e9 solid 1px;	font-family: "굴림",gulim,helvetica,sans-serif; letter-spacing:0;}
# .pd_tit_f  { float:left; width:83px;padding:15px 0 5px 22px; color:#000000; font-weight:600; font-size:12px; 	font-family: "굴림",gulim,helvetica,sans-serif;letter-spacing:0; }
# .pd_cont_f { float:left; padding:15px 0 5px 22px; font-size:12px;border-left:#e9e9e9 solid 1px;	font-family: "굴림",gulim,helvetica,sans-serif; letter-spacing:0;}
#
#
#
# .prtit5 { font-family: "굴림",gulim,helvetica,sans-serif;font-size:12px; color:#333;padding:0 5px 5px 0; font-weight:600;letter-spacing:0; }
# .prtitla5 {font-family: "굴림",gulim,helvetica,sans-serif;font-size:12px; color:#949494;padding-right:5px;letter-spacing:0; }
# .prurl { font-family: "굴림",gulim,helvetica,sans-serif;font-size:12px; color:#006a26; padding-left:15px; letter-spacing:0;   }
# .prdata { font-family: "굴림",gulim,helvetica,sans-serif;font-size:12px; color:#000; letter-spacing:0;letter-spacing:0;  }
# .prdata2 {font-family: "굴림",gulim,helvetica,sans-serif; font-size:13px; color:#000; letter-spacing:0;  }
# .prline {  border-bottom:#e9e9e9 solid 1px; width:650px; height:1px; padding:15px 0 0 0;margin-bottom:15px; clear:left; }
#
# .prtitintro{ padding: 10px 0 15px 0; font-family: "굴림",gulim,helvetica,sans-serif;font-size:12px; color:#7f7f7f;letter-spacing:0; }
# .prtitintrob{ font-family: "굴림",gulim,helvetica,sans-serif;font-size:12px; color:#000; font-weight:600;letter-spacing:0; }
#
# .prtitintro2{ padding: 20px 0 7px 0; font-family: "굴림",gulim,helvetica,sans-serif;font-size:12px; color:#7f7f7f; float:left;letter-spacing:0; }
#
# .prline2 {  border-top:#e9e9e9 solid 1px; width:300px; height:1px; padding:15px 0 0 0;margin:15px 0 0 30px; }
# .prline3 {  border-top:#e9e9e9 solid 1px; width:689px; height:1px; padding:15px 0; }
# .imprd { padding-left:20px; float:left;  }
#
#
# .icap {font-size:12px; color:#171717; height:25px; line-height:25px; text-align:center;}
# .icap1 { font-size:12px; color:#999; font-weight:600;height: 15px; }
#
#
# .popularinfo {   color:#949494; }
# .popularinfo1 { font-size:13px; font-weight:600; color:#32363e; letter-spacing:-0.5px; line-height:16px; }
# .popularinfo3 {  font-size:11px; color:#949494; text-decoration:underline; letter-spacing:-1px; }
#
#
#
# .prpolc { color:#7c7d7e; font-size:12px; }
# a.prmlnk { color:#FBE901; font-size:12px; text-decoration:underline;font-family: "굴림",gulim,helvetica,sans-serif;letter-spacing:0;  }
# .hightxt { font-size:11px; color:#FFFFFF; background-color:#FBE901;  padding:2px 6px; margin-left:5px;  text-align:center; }
# .tcateline { height:33px; width:100%; border-bottom:#FBE901 solid 2px; background-color:#fdfdfd; }
# .primwh { width:230px; height:170px; }
# .brdind { width: 319px;
# padding: 0 0 0 30px; }
# .brdind li { }
#
# .premi_dt { width: 586px;
# height: 172px;
#
# padding: 21px 24px;
# border: #e7ebef solid 3px;
# margin-left:20px;
# }
# .simgset { padding:15px 0 0 10px; }
#
# .mlfimg1 { width:228px; height:168px ; border:#dbdbdb solid 1px;}
# .mrgimg2, .mrgimg3 , .mrgimg4 { width:98px; height:58px ;border:#e7ebef solid 1px;}
#
#
# .prstit {
# 	clear:left;
# 	text-align:left;
# 	padding:0 0 7px 0;
# 	color: #00c;
# 	font-size:13px;
# 	text-decoration:underline;
# 	font-weight:600;
#
#
#
# }
#
#
# .layer_area99 {position:absolute; left:50%; top:50%; padding:0;}
# .layer99 { display: none ; position:fixed; _position:absolute; top:0; left:0; width:100%; height:100%; z-index:10000;}
# .open99 {display:block;}
# .layer99 .bg99 {position:absolute; top:0; left:0; width:100%; height:100%; background:#000; opacity:.5; filter:alpha(opacity=50);}
# .loginbox {
#
# 	width:630px;
# 	height:600px;
#
# }
#
#
# .primapp { position:absolute; left:610px; }
# .cusapp { position:absolute; left:500px; }
# .cusmodi { position:absolute; left:580px; }
# .setvisible { visibility:visible !important ; }
#
#
#
#
#
#
#
#
#
#
#
#
# .brinfo {
#
# 	padding:4px 11px 5px 0;
#
# }
# .brmitxt {   color: #3c1e1e;
# 	font-weight:600;
#     text-decoration: none;
#     font-size: 21px;
# 	line-height:19px;}
#
# .brmitxt2 {   color: #017bff;
# 	font-weight:600;
#     text-decoration: none;
#     font-size: 21px;
# 	}
#
#
# .brmitxt3 {   color: #B61F45;
# 	font-weight:600;
#     text-decoration: none;
#     font-size: 21px;
# 	}
#
#
# .brinfo2 {
#
# 	padding:1px 11px 0 0;
#
#
# }
#
# .brstit { font-size:15px;padding:5px 11px 0 0; color:#411e1e; }
# .setft20 { font-size:17px; }
# .brandul { padding:15px 0 0 20px; height:181px; background:url(/image/brandbn.png) no-repeat 180px 135px;  }
# .brandul2 { padding:15px 0 0 20px; height:181px; background:url(/image/tymbn.png) no-repeat 180px 135px;  }
# .brdt { padding-top:11px; }
#
#
# .cbk_11  {
#    width:300px; height:196px; display: block; color: #fae900;
#   text-align:left;   border:#e3e3e3 solid 1px; margin:16px 0 0 30px;
#
#
#
# }
#
# .ad_zone  {
#    width:300px; height:250px; display: block;
#   margin:16px 0 0 30px;
#
#   position: relative;
#   border:#e8e8e8 solid 1px;
#
# }
#
#
# a.btn2_1 {display:inline-block;width:auto;margin-bottom:1px;line-height:1.0;text-align:center;color:#fff;font-size:15px;background:#017bff;cursor:pointer;padding:9px 30px; font-size:14px;}
# a.btn2_1:hover {background: #5b4039; text-decoration:none;}
#
#
# .mm_btn3, .mm_btn3:visited {
# 	background-color:#ffab23;
#
# 	text-indent:0;
# 	border:1px solid #ffab23;
# 	display:inline-block;
# 	color:#fff;
#
# 	font-size:14px;
# 	font-weight:500;
# 	font-style:normal;
# 	height:24px;
# 	line-height:24px;
# 	width:143px;
# 	text-decoration:none;
# 	text-align:center;
#
# }
# .mm_btn3:hover {
#  	color:#ffab23;
# 	background-color: #FFFFFF;
# 	text-decoration:none;
#
# }
# .mm_btn3:active {
# 	position:relative;
# 	top:1px;
# 	color:#ffab23;
# }
# .imgcs {width:105px; float:left;   }
# .lcontcs { width:65%; float:right;}
# .limgsizeset { width:70px; height:51px;border:#e8e8e8 solid 1px;  }
# .numimgss { float:right; position:relative; top:3px; }
# .currentloc { color: #411e1e !important;
# text-decoration: underline !important; }
# #workinfo { background-color:#fafafa; padding:34px 20px 28px 30px; width:340px; border-bottom:#e8e8e8 solid 1px;  }
# .keyapp { font-size: 11px;
# font-family: "굴림",gulim,helvetica,sans-serif;
# 	color: #00c; text-decoration:underline;
# 	padding: 20px 30px 0 0;
# 	letter-spacing: -2px;
# 	float:right;
# 	 }
#
# .goguk { color:#FF0000; font-size:11px; font-weight:600; text-decoration:none!important; }
# .active { text-decoration:underline; }
# .largecate {  font-size:11px;
# 	padding-left:10px;
# 	font-family: "굴림",gulim,helvetica,sans-serif ;
# 	color:#7f7f7f;  }
# .cadzn { width:300px; float:left; margin-right:15px; }
# .maptit_1 {text-align:left; padding:0 0 5px 0; font-weight:700; color:#222; font-size:14px;  }
# .pline  {
# 	height:40px;
# 	border-bottom: #ededed solid 1px;
# 	margin-bottom:20px;
# 	clear:both;
# }
# .nokeyw { color:#FF0000; font-weight:600; font-size:13px;}
# .nokeyw2 { font-family: "굴림",gulim,helvetica,sans-serif; font-size:12px;letter-spacing:0; }
# .nokeyw3 { font-family: "굴림",gulim,helvetica,sans-serif; font-size:13px; color:#000000; font-weight:600; letter-spacing:0;}
# .loadv { color:#666!important;  }
#
# </style>
# <script src="/jqy/jquery.cookie.js" type="text/javascript"/>
# <div class="layer99">
# <div class="bg99"/>
# <div class="layer_area99" id="layer199">
# <div class="loginbox">
# <div style="position:relative; width:630px; height:600px;"> <img height="600" src="http://www.isuperpage.co.kr/images/pb_popup.png" usemap="#Map"/>
# <map id="Map" name="Map">
# <area alt="자세히 보기" coords="1,1,685,421" href="/bbs/ktdc/cd_nara.asp" shape="rect" title="자세히 보기">
# </area>
# <div style=" position:absolute;left:580px;top: 20px;"><a href="#" id="layer_close99"><img alt="닫기" border="0" class="lmimg" height="22" src="/image/cls_x_off.png" width="25"/></a></div>
# </map>
# </div>
# </div>
# </div>
# <div id="content_wrap">
# <div class="top_horimenu">
# <div id="cssmenu">
# <ul>
# <li class="has-sub startli" id="csli0"><a class="m_lmenu" href="#none" onClick="fnGoDispctg2('이삿짐센터','이삿짐센터')">생활/쇼핑</a>
# <ul class="in_accd" id="csliul0">
# <li><a href="#none" onClick="fnGoDispctg2('이삿짐센터','이삿짐센터')">이삿짐센터 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('부동산중개','이삿짐센터')">부동산 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('사진관','이삿짐센터')">포토스튜디오 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('애완동물','이삿짐센터')">애완동물</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('꽃집','이삿짐센터')">꽃/화원 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('가구','이삿짐센터')">가구</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('가전','이삿짐센터')">가전/전기 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('생활용품','이삿짐센터')">생활용품 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('백화점','이삿짐센터')">백화점 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('대형마트','이삿짐센터')">대형마트</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('할인점','이삿짐센터')">할인점 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('슈퍼마켓','이삿짐센터')">슈퍼마켓</a></li>
# </ul>
# </li>
# <li class="has-sub" id="csli1"><a class="m_lmenu" href="#none" onClick="fnGoDispctg2('성형외과','성형외과')">병원/약국</a>
# <ul class="in_accd" id="csliul1">
# <li><a href="#none" onClick="fnGoDispctg2('성형외과','성형외과')">성형외과 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('피부과','성형외과')">피부과 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('치과','성형외과')">치과 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('산부인과','성형외과')">산부인과</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('안과','성형외과')">안과</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('내과','성형외과')">내과</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('병원/의원','성형외과')">기타병/의원</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('한의원','성형외과')">한의원 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('종합병원','성형외과')">종합병원 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('비뇨기과','성형외과')">비뇨기과</a></li>
# <li><a class="currentloc" href="#none" onClick="fnGoDispctg2('휴일진료','성형외과')">휴일진료 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('약국','성형외과')">약국(심야)</a></li>
# </ul>
# </li>
# <li class="has-sub" id="csli2"><a class="m_lmenu" href="#none" onClick="javascript:fnGoDispctg2('추천맛집','추천맛집');">음식/주점</a>
# <ul class="in_accd" id="csliul2">
# <li><a href="#none" onClick="fnGoDispctg2('추천맛집','추천맛집')">추천맛집 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('한식','추천맛집')">한식 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('일식','추천맛집')">일식 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('중식','추천맛집')">중식</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('고기전문점','추천맛집')">고기전문점 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('레스토랑','추천맛집')">패밀리레스토랑</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('치킨','추천맛집')">치킨 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('피자전문','추천맛집')">피자</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('족발','추천맛집')">족발/보쌈 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('패스트푸드','추천맛집')">패스트푸드</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('커피숍','추천맛집')">커피/떡/베이커리 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('일반유흥주점','추천맛집')">주점/클럽</a></li>
# </ul>
# </li>
# <li class="has-sub" id="csli3"><a class="m_lmenu" href="#none" onClick="fnGoDispctg2('웨딩홀','웨딩홀')">결혼/교육</a>
# <ul class="in_accd" id="csliul3">
# <li><a href="#none" onClick="fnGoDispctg2('웨딩홀','웨딩홀')">웨딩홀 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('웨딩샵','웨딩홀')">웨딩샵 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('혼수','웨딩홀')">혼수/보석 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('산후조리원','웨딩홀')">산후조리원</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('놀이방','웨딩홀')">놀이방</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('유치원','웨딩홀')">유치원 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('키즈카페','웨딩홀')">키즈카페 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('수능','웨딩홀')">수능/입시 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('고시원','웨딩홀')">고시/자격</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('외국어학원','웨딩홀')">어학원/유학원 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('체육관','웨딩홀')">예체능학원</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('학원','웨딩홀')">기타학원 </a></li>
# </ul>
# </li>
# <li class="has-sub" id="csli4"><a class="m_lmenu" href="#none" onClick="fnGoDispctg2('인테리어','인테리어')">주택/차량</a>
# <ul class="in_accd" id="csliul4">
# <li><a href="#none" onClick="fnGoDispctg2('인테리어','인테리어')">인테리어 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('하수구','인테리어')">하수구 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('누수탐지','인테리어')">방수/방습 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('벽지','인테리어')">도배</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('창호','인테리어')">창호/샷시 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('에이컨','인테리어')">에어컨</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('자동차정비','인테리어')">자동차정비 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('중고차매매센터','인테리어')">중고차매매 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('자동차영업소','인테리어')">자동차영업소 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('건설','인테리어')">건설</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('주유소','인테리어')">주유소 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('자동차용품','인테리어')">자동차용품</a></li>
# </ul>
# </li>
# <li class="has-sub" id="csli5"><a class="m_lmenu" href="#none" onClick="fnGoDispctg2('비만관리','비만관리')">미용/건강</a>
# <ul class="in_accd" id="csliul5">
# <li><a href="#none" onClick="fnGoDispctg2('비만관리','비만관리')">비만관리 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('피부관리','비만관리')">피부관리 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('네일아트','비만관리')">네일아트 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('미용실','비만관리')">미용실</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('헬스','비만관리')">헬스 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('건강식품','비만관리')">건강식품</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('탈모','비만관리')">탈모/가발 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('사우나','비만관리')">사우나/찜질방 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('의료기기','비만관리')">의료기기 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('마사지','비만관리')">마사지</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('화장품','비만관리')">화장품 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('정관장','비만관리')">정관장</a></li>
# </ul>
# </li>
# <li class="has-sub" id="csli6"><a class="m_lmenu" href="#none" onClick="fnGoDispctg2('렌터카','렌터카')">여행/레저</a>
# <ul class="in_accd" id="csliul6">
# <li><a href="#none" onClick="fnGoDispctg2('렌터카','렌터카')">렌터카 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('여행사','렌터카')">여행사 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('호텔','렌터카')">호텔 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('모텔','렌터카')">모텔</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('펜션','렌터카')">펜션 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('콘도','렌터카')">콘도/리조트</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('공원관리사무소','렌터카')">테마파크</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('수상레포츠','렌터카')">레포츠용품 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('취미','렌터카')">취미 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('오락','렌터카')">오락</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('악기','렌터카')">악기 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('굿스테이','렌터카')">굿스테이</a></li>
# </ul>
# </li>
# <li class="has-sub" id="csli7"><a class="m_lmenu" href="#none" onClick="fnGoDispctg2('가사도우미','가사도우미')">생활 서비스</a>
# <ul class="in_accd" id="csliul7">
# <li><a href="#none" onClick="fnGoDispctg2('가사도우미','가사도우미')">가사도우미 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('출장요리','가사도우미')">출장요리 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('대리운전','가사도우미')">대리운전 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('콜택시','가사도우미')">콜택시</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('장례상조','가사도우미')">장례상조 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('컴퓨터','가사도우미')">컴퓨터</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('렌탈','가사도우미')">렌탈 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('열쇠','가사도우미')">열쇠/금고 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('택배','가사도우미')">택배/화물 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('통신','가사도우미')">통신상품</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('결혼','가사도우미')">결혼정보 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('종교단체','가사도우미')">종교단체</a></li>
# </ul>
# </li>
# <li class="has-sub" id="csli8"><a class="m_lmenu" href="#none" onClick="fnGoDispctg2('사주','사주')">전문서비스</a>
# <ul class="in_accd" id="csliul8">
# <li><a href="#none" onClick="fnGoDispctg2('사주','사주')">사주 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('청소','사주')">청소 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('광고','사주')">광고 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('방문교육','사주')">방문교육</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('창업상담','사주')">창업상담 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('자동차견인','사주')">견인서비스</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('폐차','사주')">폐차서비스 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('개인회생','사주')">개인파산/회생 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('도우미','사주')">직업소개 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('심부름센터','사주')">심부름센터</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('법무','사주')">법무 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('회계','사주')">회계세무</a></li>
# </ul>
# </li>
# <li class="has-sub endli" id="csli9"><a class="m_lmenu" href="#none" onClick="fnGoDispctg2('긴급전화','긴급전화')">콜센터</a>
# <ul class="in_accd" id="csliul9">
# <li><a href="#none" onClick="fnGoDispctg2('긴급전화','긴급전화')">긴급전화 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('민원전화','긴급전화')">민원전화 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('금융','긴급전화')">금융 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('방송','긴급전화')">방송</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('공연','긴급전화')">공연/문화 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('서비스','긴급전화')">서비스</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('통신','긴급전화')">통신 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('교통','긴급전화')">교통 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('쇼핑','긴급전화')">쇼핑/음식 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('관광','긴급전화')">관광/레저</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('의료','긴급전화')">의료 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('공공기관','긴급전화')">정부/단체</a></li>
# </ul>
# </li>
# <li class="has-sub endli" id="csli10"><a class="m_lmenu" href="#none" onClick="fnGoDispctg2('시구군청','시구군청')">주요기관</a>
# <ul class="in_accd" id="csliul10">
# <li><a href="#none" onClick="fnGoDispctg2('시구군청','시구군청')">시/군/구청 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('법원','시구군청')">법원/검찰 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('세무서','시구군청')">세무서 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('경찰서','시구군청')">경찰서</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('학교','시구군청')">초/중/고등학교</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('대학교','시구군청')">대학교/기타</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('병무청','시구군청')">병무청 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('우체국','시구군청')">우체국 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('터미널','시구군청')">터미널/기차역 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('은행','시구군청')">은행</a></li>
# <li><a href="#none" onClick="fnGoDispctg2('증권','시구군청')">증권/카드 </a></li>
# <li><a href="#none" onClick="fnGoDispctg2('보험','시구군청')">보험</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <script language="javascript">
#
#
# function setmCookie(name, value)
# {
#
# 		$.cookie(name, value, {expires:30});
# 		return;
#
# }
#
#
# function getmCookie(name)
# {
# 	var cookie_val = $.cookie(name);
# 	if ( typeof (cookie_val) == "undefined" || cookie_val == null ) return [];
#
# 	return cookie_val;
# }
#
#
# //alert(getmCookie("cur_page"));
# var cupag = getmCookie("cur_page");
# var curtc= getmCookie("cur_topca");
# var curset;
#
# if (curtc != ""){
#  curset = curtc;
# }else {
#   curset = cupag;
# }
#
#
# 	if(curset == "이삿짐센터"){
# 	   $("#csli0").addClass( "active has-sub" );
# 	   $("#csliul0").addClass( "setvisible in_accd" );
# 	  }
# 	  else if(curset == "성형외과"){
#
# 	  $("#csli1").addClass( "active has-sub" );
# 	  $("#csliul1").addClass( "setvisible in_accd" );
#
# 	  }
# 	  else if(curset == "추천맛집"){
# 	  $("#csli2").addClass( "active has-sub" );
# 	  $("#csliul2").addClass( "setvisible in_accd" );
#
# 	  }
# 	  else if(curset == "웨딩홀"){
# 	  $("#csli3").addClass( "active has-sub" );
# 	  $("#csliul3").addClass( "setvisible in_accd" );
#
# 	  }
# 	  else if(curset == "인테리어"){
# 	  $("#csli4").addClass( "active has-sub" );
# 	  $("#csliul4").addClass( "setvisible in_accd" );
#
# 	  }
# 	  else if(curset == "비만관리"){
# 	  $("#csli5").addClass( "active has-sub" );
# 	  $("#csliul5").addClass( "setvisible in_accd" );
#
# 	  }
#
# 	  else if(curset == "렌터카"){
# 	  $("#csli6").addClass( "active has-sub" );
# 	  $("#csliul6").addClass( "setvisible in_accd" );
#
# 	  }
# 	  else if(curset == "가사도우미"){
# 	  $("#csli7").addClass( "active has-sub" );
# 	  $("#csliul7").addClass( "setvisible in_accd" );
#
# 	  }
# 	  else if(curset == "사주"){
# 	  $("#csli8").addClass( "active has-sub" );
# 	  $("#csliul8").addClass( "setvisible in_accd" );
#
# 	  }
# 	  else if(curset == "긴급전화"){
# 	  $("#csli9").addClass( "active has-sub" );
# 	  $("#csliul9").addClass( "setvisible in_accd" );
#
# 	  } else if(curset == "시구군청"){
# 	  $("#csli10").addClass( "active has-sub" );
# 	  $("#csliul10").addClass( "setvisible in_accd" );
#
# 	  } else {
# 	  $("#csli0").addClass( "active has-sub" );
# 	  $("#csliul0").addClass( "setvisible in_accd" );
#
# 	  }
#
# 	  //setmCookie("cur_topca","");
#
# 	  </script>
# <div class="tcateline"/>
# <div id="top" style="padding:0; margin:0 auto; width:1080px; height:auto; ">
# <div id="contentarea">
# <div id="centerarea" style="position:relative;">
# <style type="text/css">
#
# .premi_dt { position:relative; border:0; }
# #pradact { position:absolute; left: 542px;
# top: 80px; }
# </style>
# <div id="premiumarea">
# <div class="prtitintro"><span class="prtitintrob">프리미엄 브랜드</span> 검색 결과  입니다.<img src="/image/ad_exp.png"/>
# <div class="premi_dt" style="padding:0 0 0 0">
# <div id="pradact"><img src="/image/prad_ac.gif"/></div>
# <img border="0" src="/image/pr_ad.png" usemap="#Map9"/>
# <map id="Map9" name="Map9">
# <area alt="신청하기" coords="32,167,239,209" href="/bbs/ktdc/premium_ad_info.asp" shape="rect"/>
# <area alt="문의하기" coords="241,168,378,212" href="/bbs/ktdc/premium_ad_info.asp" shape="rect"/>
# </map>
# </div>
# </div>
# <script src="/StatLog/Statbrlinklog.asp?adid=001"/>
# <div id="search_result">
# <ol class="answerlist">
# <li>prline&gt;</li><li class="genarea1"><div class="stitwrap"><span class="stit">일반 검색 결과 '휴일진료' 입니다.</span><span class="cusapp"><a href="/bbs/ceo/regi_info.asp"><img src="/images/cus_ap.png"/></a><span class="cusmodi"><a href="/bbs/ceo/regi_info.asp"><img src="/images/cus_modi.png"/></a></span><div class="stit2">검색결과 - '' 근처 '<span class="scword">휴일진료</span>' 검색결과</div></span><li onClick="javascript:google.maps.event.trigger(globalmarkers[0], 'click');" style="background:url(/image/n0.png) no-repeat 20px 6px;"><div class="tit_list"><a class="l_tit" href="search_detail.asp?id=3448">중정한의원</a><span class="largecate"/><span class="l_ser">휴일진료병원</span></div><div class="l_cont"><span class="phone">02-3789-7017</span><span>서울 중구 명동1가 7-1</span><span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 명동길 55</span></span></div><li onClick="javascript:google.maps.event.trigger(globalmarkers[1], 'click');" style="background:url(/image/n1.png) no-repeat 20px 6px;"><div class="tit_list"><a class="l_tit" href="search_detail.asp?id=4061">신농백초한의원</a><span class="largecate"/><span class="l_ser">휴일진료병원</span></div><div class="l_cont"><span class="phone">02-736-4644</span><span>서울 중구 정동 1-48</span><span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 세종대로21길 53</span></span></div><li onClick="javascript:google.maps.event.trigger(globalmarkers[2], 'click');" style="background:url(/image/n2.png) no-repeat 20px 6px;"><div class="tit_list"><a class="l_tit" href="search_detail.asp?id=4109">서울백병원</a><span class="largecate"/><span class="l_ser">휴일진료병원</span></div><div class="l_cont"><span class="phone">02-2270-0119</span><span>서울 중구 저동 2가 85</span><span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 </span></span></div><li onClick="javascript:google.maps.event.trigger(globalmarkers[3], 'click');" style="background:url(/image/n3.png) no-repeat 20px 6px;"><div class="tit_list"><a class="l_tit" href="search_detail.asp?id=4110">서울내과의원</a><span class="largecate"/><span class="l_ser">휴일진료병원</span></div><div class="l_cont"><span class="phone">02-2256-7575</span><span>서울 중구 신당6동 294-13</span><span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 </span></span></div><li onClick="javascript:google.maps.event.trigger(globalmarkers[4], 'click');" style="background:url(/image/n4.png) no-repeat 20px 6px;"><div class="tit_list"><a class="l_tit" href="search_detail.asp?id=4111">반도병원</a><span class="largecate"/><span class="l_ser">휴일진료병원</span></div><div class="l_cont"><span class="phone">02-2252-0202</span><span>서울 중구 신당2동 422-4</span><span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 </span></span></div><li onClick="javascript:google.maps.event.trigger(globalmarkers[5], 'click');" style="background:url(/image/n5.png) no-repeat 20px 6px;"><div class="tit_list"><a class="l_tit" href="search_detail.asp?id=4112">하버드마취통증의학과의원</a><span class="largecate"/><span class="l_ser">휴일진료병원</span></div><div class="l_cont"><span class="phone">02-2236-8188</span><span>서울 중구 무학동 1</span><span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 다산로 245</span></span></div><li onClick="javascript:google.maps.event.trigger(globalmarkers[6], 'click');" style="background:url(/image/n6.png) no-repeat 20px 6px;"><div class="tit_list"><a class="l_tit" href="search_detail.asp?id=4113">청구경희한의원</a><span class="largecate"/><span class="l_ser">휴일진료병원</span></div><div class="l_cont"><span class="phone">02-2236-1075</span><span>서울 중구 신당4동 309-8</span><span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 </span></span></div><li onClick="javascript:google.maps.event.trigger(globalmarkers[7], 'click');" style="background:url(/image/n7.png) no-repeat 20px 6px;"><div class="tit_list"><a class="l_tit" href="search_detail.asp?id=4114">유태석내과의원</a><span class="largecate"/><span class="l_ser">휴일진료병원</span></div><div class="l_cont"><span class="phone">02-2233-7076 ...
# </li>
# <div class="navs"> </div>
# <script src="/search/opbeansMap.js" type="text/javascript"/>
# <script type="text/javascript">
#
#
#
#
#
#
# 	function initialize() {
# 	//log.debug("지도 시작");
# 		var aaa =  "{ lat : 37.56418965 , lng :126.9853678 } ";
# 		var address= eval("("+ aaa +")"); //{ lat : 37.4999072, lng :127.0373932} ;//"서울시 강남구 역삼동";
# //log.debug("address:"+address);
#         var type = Object.prototype.toString.apply(address);
# 		// Google Map Option (참조 : https://developers.google.com/maps/documentation/javascript/reference?hl=ko-KR#MapOptions)
# 		var mapOptions = {
# 			address: address,													// google.maps.MapOptions Properties의 center 값을 주소를 입력받아 자동으로 생성.
# 			zoom: 14,
# 			minZoom : 6,
# 			maxZoom : 17,
# 			mapTypeId: google.maps.MapTypeId.ROADMAP,
# 			disableDoubleClickZoom : false,
# 			mapTypeControl : false,											// 지도 및 위성 간에 전환할 수 있게 해주는 MapType 컨트롤. 기본적으로 이 컨트롤은 표시되며 지도의 오른쪽 상단에 나타남.
# 			panControl : true,												// 지도 이동 컨트롤. 기본적으로 이 컨트롤은 표시되며 지도의 왼쪽 상단에 표시됨
# 			zoomControl : true,												// 확대 or 축소 컨트롤. 기본적으로 이 컨트롤은 표시되며 지도의 왼쪽 상단에 표시됨.
# 			zoomControlOptions : {
# 				position : google.maps.ControlPosition.RIGHT_TOP,
# 				style : google.maps.ZoomControlStyle.DEFAULT
# 			},
# 			streetViewControl : true,										// 스트리트 뷰 컨트롤, 기본적으로 이 컨트롤은 표시되며 지도의 오른쪽 상단에 나타남.
# 			scaleControl : false,												// 간단한 지도 축척을 제공하는 Scale 컨트롤. 기본적으로 이 컨트롤은 표시되지 않으며 지도의 왼쪽 하단에 나타남.
# 			rotateControl : false,												// 45° 이미지의 방향을 조정하기 위한 회전 컨트롤. 기본적으로 컨트롤 표시 여부는 현재의 확대/축소 및 위치에서 지정된 지도 유형에 대해 45° 이미지가 존재하는지 또는 부재하는지에 따라 결정.
# 			overviewMapControl : false									// 평면 지도 컨트롤. 평면 지도 컨트롤은 완전히 표시되어 미리보기 이미지 평면 지도를 표시하거나 최소화된 상태로 축소되어 표시됨. 기본적으로 사용하지 않도록 설정되며 축소된 상태로 표시됨.지정합니다.
# 		};
# 		// Google Map에 Marker로 출력될 좌표 리스트
#
# 		var gmarstart, gmarkerend;
# 		gmarstart = "{ markers : [ ";
# 		gmarkerend = "]} ";
#
# ...
# </br>
# </div>
# </div>
# </div>
# <style type="text/css">
# .f_wrap {  margin:0 auto; position:absolute; left:700px; top:15px;   padding:0; }
# .select{ position:relative; line-height:normal; display:inline-block; *display:inline; vertical-align:middle; background:#fff; *zoom:1; text-align:left}
# .select *{ margin:0; padding:0; cursor:pointer; font-size:12px; font-family:Tahoma, Sans-serif;}
# .select .myValue{ position:relative; z-index:2; left:0; top:0; border:1px solid #bababa; color:#666; line-height:19px; _line-height:normal; text-align:left; overflow:visible; background:transparent;}
# .select .myValue.selected{ font-weight:bold;}
# .select .myValue{ height:21px; width:100%; text-indent:5px; *text-indent:0; *padding-left:5px;}
# .select .ctrl{ position:absolute; top:0; right:0; width:18px; height:19px; border:1px solid #bababa; border-left:1px solid #eaeaea; background:#fff;}
# .select .arrow{ position:absolute; width:0; height:0; top:9px; right:6px; line-height:0; font-size:0; border-top:3px solid #999; border-left:3px solid #fff; border-right:3px solid #fff;}
# .select ul{ top:20px; left:0; width:100%; list-style:none; border:0; border-top:1px solid #bababa; border-bottom:1px solid #bababa; background:#fff; overflow:hidden;}
# .select ul.aList{ display:none;}
# .select li{ position:relative; overflow:hidden; white-space:nowrap; height:18px; border-left:1px solid #bababa; border-right:1px solid #bababa;}
# .select li a{ display:block; text-indent:8px; *text-indent:6px; height:18px; line-height:18px; color:#767676; background:#fff; text-decoration:none;}
# .select li:hover *{ background:#999; color:#fff;}
#
#
#
#
# </style>
# <script type="text/javascript">
# <!--
#
# $('.select').click(function(){
# 		if( $(".aList").css("display")=="none" ) {
# 			$('.aList').css({"display":"block" });
# 		}
# 		else {
# 			$('.aList').css({"display":"none" });
# 		}
# 	});
#
# var clicked_link_gnb = 0;
# var isSearchInit = false;
# $(document).ready(function(){
# 	$("#ctg_bt").bind("click keypress", function () {
#
#
#
# 		if($.trim($("#ctg_all").html()) == ""){
#
# 				fnToggleCatg('ctg_bt', 'ctg_all');
# 		} else {
#
# 			fnToggleCatg('ctg_bt', 'ctg_all');
# 		}
# 	});
#
#
#
#
# function fnToggleCatg(tabId, targetId){
#     var stat = $("."+targetId).css('display');
#
#
#
# 	if (stat == 'none'){
# 		$("."+targetId).slideDown(500);
# 		if ( $("#"+tabId)[0] ) {$("#"+tabId)[0].className = $("#"+tabId)[0].className.replace("off", "on");}
#     }else{
# 		$("."+targetId).slideUp(300);
# 		if ( $("#"+tabId)[0] ) {$("#"+tabId)[0].className = $("#"+tabId)[0].className.replace("on", "off");}
#     }
# }
#
#
#
#
#
#
#
# $('.m_lmenu').hover(function() {
# //alert($(this).css('background-image'));
#  $(this).css('background-image', $(this).css('background-image').replace('off','on'));
#
# },function() {
#
#   $(this).css('background-image', $(this).css('background-image').replace('on','off'));
# });
#
#
#
#
#
#
#
#
# });
#
#
#
#
# function fnGoDispctg2(category , curtc)
# {
#
# if ( $("#city").val().length == 0 )
# 		{
# 		    alert ("지역을 먼저 검색해주세요!");
# 		    return;
# 		}
#
# 	setmCookie("cur_page",category);
# 	setmCookie("cur_topca",curtc);
#
# 	var frm = document.searchForm;
# 	frm.action = "/search.asp";
#
# 	frm.searchWord.value = $.trim(category);
#
# 	frm.submit();
# }
#
#
#
#
# function fnGoDispctg(category )
# {
#
# if ( $("#city").val().length == 0 )
# 		{
# 		    alert ("지역을 먼저 검색해주세요!");
# 		    return;
# 		}
#
#
#
# 	var frm = document.searchForm;
# 	frm.action = "/search.asp";
#
# 	frm.searchWord.value = $.trim(category);
#
# 	frm.submit();
# }
#
#
#
# function search( sword, mode )
# {
#
#     // 인기업종 검색
#     if ( mode && mode == "fav" )
#     {
#          $("#search_word").val(sword);
#     }
#
# 	var frm = document.searchForm;
# 	frm.action = "/search.asp";
#
#     if ( typeof(sword) != "undefined" )
#     {
#         frm.searchWord.value = sword;
#
#     } else {
#
#         var checkVal ="업종, 상호, 전화번호 검색";
# 		if ( $("#search_word").val() == checkVal || $("#search_word").val().length == 0 )
# 		{
# 		    alert ("검색어를 입력하세요!");
# 		    return;
# 		}
# 		frm.searchWord.value = $("#search_word").val();
# 	}
# 	frm.submit();
# }
#
#
#
# $(document).ready(function($) {
#     // 홈페이지로 이동하기....
# 	//var homepage = getURL();
#
#
#
#
# 	$("#query_submit").on('click', function(event) {
# 		search();
#
# 	});
#
#
#
#
# 	// 검색어 및 지역정보 설정관련 이벤트 등록...
# 	Regsearchlocalevent();
#
# 	// 이전에 쿠키에 값이 있으면, 표시안하게 우선 개발하자...
# 	coord_arr = getCookie("coord_his");
# 	dong_arr = getCookie("dong_his");
# 	addr_arr = getCookie("addr_his");
#
#
# 	if ( typeof (coord_arr) != "undefined" && coord_arr.length != 0 )
# 	{
# 	    var tmp_x = coord_arr[0].split("-")[0];
# 	    var tmp_y = coord_arr[0].split("-")[1];
# 	    var tmp_dong = dong_arr[0];
# 	    var tmp_addr = addr_arr[0];
#
#
# 		var addr_arr = tmp_addr.split(" ");
#
# 	var addrlang = addr_arr.length-1;
# 	var city, gu,dong,addr4 ;
# 	city="";gu="";dong="";addr4="";
#
#
# 	   if(addrlang==0){
# 		   city= addr_arr[addr_arr.length-1];
# 		   }
# 	   else if(addrlang==1){
# 		city= addr_arr[addr_arr.length-2];
# 		gu= addr_arr[addr_arr.length-1];
# 		   }
# 	   else if(addrlang==2){
# 		   city= addr_arr[addr_arr.length-3];
#   		   gu= addr_arr[addr_arr.length-2];
# 		   dong= addr_arr[addr_arr.length-1];
# 		   }
# 	else if(addrlang==3){
# 		   city= addr_arr[addr_arr.length-4];
#   		   gu= addr_arr[addr_arr.length-3];
# 		   dong= addr_arr[addr_arr.length-2];
# 		   addr4= addr_arr[addr_arr.length-1];
# 		   }
#
#
#
#
#
#
#
# 	    $("#x").val(tmp_x);
# 	    $("#y").val(tmp_y);
# 	   $("#city").val(city);
# 	$("#gu").val(gu);
# 	$("#dong").val(dong);
# 	$("#addr4").val(addr4);
# 	    $("#addr").val(tmp_addr);
#
# 	    $("#Autocomplete_addr_a").val( tmp_addr );
#
# 	}else {
# 	    // IP 타게팅한 값으로 설정한다.
# 	    searchCurrentLoc();
#
# 	}
#
#
# });
#
#
#
#
# //-->
# </script>
# </div>
# </div>
# <script type="text/javascript">
# <!--
# function myTrim(x) {
#     return x.replace(/^\s+|\s+$/gm,'');
# }
#
#
#
# function paging(page_num,padcnt) {
#
#     var addrelistp ;
# 	addrelistp  = "";
#
# 	var x = $('#x').val();
# 	var y = $('#y').val();
# 	var searchWord = $('#search_word').val();
# 	var address = $('#addr').val();
#     var c,g,d,d2;
# 	c="서울";g="중구";d="";d2="";
#
#
#
# //var aaa="/search/s_pagedata_page.asp?x=" + x + "&y=" + y + "&searchWord=" + searchWord + "&page=" + page_num + "&city=" + c + "&gu=" + g + "&dong=" + d+ "&pdc=" + padcnt
#
#
#
#
# $.ajax({
#                         url: "/search/s_pagedata_page.asp",
#                         type: "GET",
#                         data : "x=" + x + "&y=" + y + "&searchWord=" + searchWord + "&page=" + page_num + "&city=" + c + "&gu=" + g + "&dong=" + d + "&addr4=" + d2 + "&pdc=" + padcnt  ,
# 						error : function(result) {
# 						console.log(result.responseText); $("#answerlist").remove(); html = "<li class='poi_item'>"+"Response Error("+result.status+")"+", Msg: " +result+ "</li>";
# 			  $(".answerlist").append(html);
#
#
# 		},
# 					    success: function (data) {
# 					//console.log(data);
# 					poi_proc(data);
# 					//	$("#answerlist").html(data);
# 					//	initialize();
#                         }
#                     });
#
#
#
#
#
# 	return;
#
# }
#
#
#
#
# function poi_proc(res) {
#
#
#
#
#
#
#
#
# 	var firstadlist;
# 	 firstadlist   = "{prmList:[]}";
#
#
# 	 var firstadlist2 = eval("("+ firstadlist +")");
#
#
# 	var html = "";
# 	//html += "<div class='tit2'>업체 정보</div>";
#     var prmList = firstadlist2.prmList;
#
# 	for (var k = 0; k < prmList.length; k++) {
# 		var prmInfo = prmList[k];
# 		if(k==0)
# 		html += "<li class=linegaps2></li><li class='premiuarea' style='padding-left:30px;width:689px;height: 50px;'><div class='prtitintro2'> <span class='prtitintrob'>스페셜 키워드 `휴일진료`</span> 관련 광고 입니다.&nbsp;</div><a href='/bbs/ktdc/keyword_ad_info.asp'><div class='keyapp'>스페셜 키워드 신청 ＞</div></a></li>";
#
# 		html += "<li class='premiuarea'>";
# 		html += "<div class='imgcs'><img src='" + prmInfo.image + "' onerror='javascript:this.src=\"/image/agent1.jpg\"' class='limgsizeset' />   <img src='/image/p" +  (k)  + ".png' class='numimgss' ></div><div class='tit_list' style='padding-left:115px;'><strong><a href='search_pdetail.asp?id=" + prmInfo.num + "' class='l_tit'>" + prmInfo.sangho + "</a></strong><span class='largecate'></span><span class='l_ser'>" + prmInfo.clas_name + "</span></div>";
# 		html += "   <div class='l_cont'><span class='phone2'>" + prmInfo.tel + "</span><span>" + prmInfo.t_addr + "</span>";
#
#
# 		//if (prmInfo.road_addr != "")
# 			html += "<span class='load2'><img src='/image/loadi.png'></span><span class='loadv'> " + prmInfo.city + " " + prmInfo.gu + " " +prmInfo.road_addr + "</span>" ;
#
# 		html += " </div></li>";
#
# 	}
#
#
# 	var poiList = res.poiList;
#
# 	// #2 data
# 	for (var i = 0; i < poiList.length; i++) {
# 		var poiInfo = poiList[i];
# 		   if(i==0){
#
# 		   if(prmList.length>0){
# 				 html += "<li class=linegaps0></li><li class=linegaps></li><li class='genarea'><div class='stitwrap'><span class='stit'>일반 검색 결과 '휴일진료' 입니다.</span><span class='cusapp'><a href='/bbs/ceo/regi_info.asp'><img src='/images/cus_ap.png'></a></span><span class='cusmodi'><a href='/bbs/ceo/regi_info.asp'><img src='/images/cus_modi.png'></a></span></div><div class='stit2'>검색결과 - '' 근처 '<span class='scword'>휴일진료</span>' 검색결과</div></li>";
# 			}else{
# 			      html += "<li class=prline></li><li class='genarea1'><div class='stitwrap'><span class='stit'>일반 검색 결과 '휴일진료' 입니다.</span><span class='cusapp'><a href='/bbs/ceo/regi_info.asp'><img src='/images/cus_ap.png'></a></span><span class='cusmodi'><a href='/bbs/ceo/regi_info.asp'><img src='/images/cus_modi.png'></a></span></div><div class='stit2'>검색결과 - '' 근처 '<span class='scword'>휴일진료</span>' 검색결과</div></li>";
# 			}
# 			}
#
#
#
# 		html += "<li style='background:url(/image/n" + (i) + ".png) no-repeat 20px 6px;'>";
# 		html += "<div class='tit_list'><a href='search_detail.asp?id=" + poiInfo.num + "' class='l_tit'>" + poiInfo.sangho + "</a><span class='largecate'></span><span class='l_ser'>" + poiInfo.clas_name + "</span></div>";
# 		html += "   <div class='l_cont'><span class='phone'>" + poiInfo.tel + "</span><span>" + poiInfo.t_addr + "</span>";
#
#
#
# 		//if (poiInfo.road_addr != "")
# 			html += "<span class='load2'><img src='/image/loadi.png'></span><span class='loadv'> " + poiInfo.city + " " + poiInfo.gu + " " +poiInfo.road_addr + "</span>" ;
#
# 		html += " </div></li>";
#
# 	}
# //log.debug(html);
# 	// console.log(res.totalCount +"," + res.pageSize );
# 	// #3 paging
#
# //	html += "</div>";
# 	$(".answerlist").html(html);
#
# 	var navi0 = page_nav(res.currentPage, 10, res.totalCount,	res.pageSize, "paging",0);
# 	//alert(navi0);
# 	$(".navs").html(navi0);
# 	//html += navi0;
# 	//$(".largecate").html($(".active a").html()+" >");
# 	var markers ,firstmarker;
# 	var addrelistp   = "";
# 	markers = "{ markers : [";
# 	 markers += addrelistp ;
# 	 if(addrelistp !=""){
# 	 markers += ", ";
# 	 }
# 	for (var i = 0; i < poiList.length; i++) {
# 	  var poiInfo = poiList[i];
# 	  if (i>0){
# 	    markers += ", ";
# 	  }
#
# 	  	  var continfo = "<ul class=mapifwrap><li><div class=maptit1><a href=search_detail.asp?id=" + poiInfo.num + " >" + poiInfo.sangho + "</a></div></li><li><span class=mphe1>" + poiInfo.tel + " [</span> " + poiInfo.clas_name + " <span class=mphe1>]</span></li><li>" + poiInfo.t_addr + "</li>";
# if (poiInfo.road_addr !="")
#     continfo +=  "<li><span class=load>도로</span> " + poiInfo.city + " " + poiInfo.gu + " " + poiInfo.road_addr + "</li>";
#
#
# continfo +=  "</ul>"
#
#
#
# 	  markers += "{ lat: " + poiInfo.lat + ", lng : " + poiInfo.lng + ", title : '" + poiInfo.sangho + "', cont : '" + continfo + "', level: 'n" + i + "'  } ";
#
# 	}
# 	markers += "]}";
#
#     firstmarker = "{ lat : 37.56418965 , lng :126.9853678 } ";
#
#
#
# 	//log.debug("premiumadmarker:"+addrelistp);
# 	//log.debug("markers:"+markers);
#
# 	initialize2(firstmarker,markers);
#
#
# }
#
# function page_nav(currentPage, rowsPerPage, totalCount, pageSize, func0 ,padcnt)
# {
#     //log.debug (currentPage+","+rowsPerPage+","+totalCount+","+pageSize+","+func0);
# 	//2,10,176,10,paging
#     var pageRemain = totalCount % ( rowsPerPage * pageSize );
#     if (pageRemain > 0 ) {pageRemain = 1;}
#
#
#     var pageGroupCount  = parseInt( totalCount / (rowsPerPage * pageSize ) ) + pageRemain;
#
#     var pageGroupNumber = parseInt (currentPage / pageSize) + 1;
# 	//log.debug("pageGroupNumber:"+pageGroupNumber);
#
#
#     if (currentPage % pageSize == 0)
#     {
# 	    pageGroupNumber = pageGroupNumber - 1;
# 	}
# 	//console.log ("#2:"+pageGroupCount+","+pageGroupNumber);
#
#     var pageCount = parseInt ( totalCount / rowsPerPage );
#     if((totalCount % rowsPerPage) > 0) {   pageCount = pageCount + 1;}
#
#     var startPage = (pageSize * (pageGroupNumber - 1 )) + 1;
# //	log.debug("startPage:"+startPage);
#
#     var endPage   = parseInt(startPage) + parseInt(pageSize) - 1 ;
# //	log.debug("pageSize:"+pageSize);
# //	log.debug("endPage:"+endPage);
#     if (endPage > pageCount) { endPage = pageCount;}
#
#     var prevPageNumber = ((pageGroupNumber - 2) * pageSize) + 10;
#     var nextPageNumber = pageGroupNumber * pageSize + 1;
#
#     if ( totalCount <= 0 ) return "";
#
# 	startPage =  parseInt( startPage);
# 	endPage   =  parseInt( endPage);
# 	prevPageNumber =  parseInt( prevPageNumber);
# 	pageGroupNumber =  parseInt( pageGroupNumber);
#
# 	var html = "<ul class='pagination pagination-sm'>";
#
# 	if ( currentPage != 1 )
# 	{
# 	    html    += "<li><a href='javascript:"+func0+"(\"1\",\"" + padcnt + "\");'>≪</a></li>";
# 	}
#
# 	if ( pageGroupNumber > 1)
# 	{
# 	    html    += "<li><a  href='javascript:"+func0+"(\"" + prevPageNumber+ "\",\"" + padcnt + "\");'>＜</a></li>";
# 	}
# //	log.debug(endPage);
# 	for ( var index = startPage ; index <=  endPage ; index ++ )
# 	{
# 	    if ( currentPage == index )
# 	    {
# 	        html    += "<li><a href='javascript:return false;' class='currentp'>" + index + "</a></li>";
#
# 	    } else {
# 	        html    += "<li><a href='javascript:"+func0+"(\"" + index + "\",\"" + padcnt + "\");'>" + index + "</a></li>";
# 	    }
# 	}
#
#     if ( nextPageNumber < pageCount )
#     {
# 	    html    += "<li><a  href='javascript:"+func0+"(\"" + nextPageNumber+ "\",\"" + padcnt + "\");'>＞</a></li>";
#     }
#
#     if ( currentPage != pageCount)
#     {
# 	    html    += "<li><a  href='javascript:"+func0+"(\"" + pageCount+ "\",\"" + padcnt + "\");'>≫</a></li>";
#     }
#
# 	html    += "</ul>";
# 	return html;
# }
#
#
# var navi0 = page_nav(1, 10, 16,	10, "paging",0);
# //	alert(navi0);
# 	$(".navs").html(navi0);
#
#
#
#
# function search2( sword, mode )
# {
#     // 인기업종 검색
#     if ( mode && mode == "fav" )
#     {
#          $("#search_word").val(sword);
#     }
#
# 	var frm = document.searchForm;
# 	frm.action = "/search_map.asp";
#
#     if ( typeof(sword) != "undefined" )
#     {
#         frm.searchWord.value = sword;
#
#     } else {
#
#         var checkVal ="업종, 상호, 주소, 전화번호 검색";
# 		if ( $("#search_word").val() == checkVal || $("#search_word").val().length == 0 )
# 		{
# 		    alert ("검색어를 입력하세요!");
# 		    return;
# 		}
# 		frm.searchWord.value = $("#search_word").val();
# 	}
# 	frm.submit();
# }
#
#
#
# $(document).ready(function($) {
#     // 홈페이지로 이동하기....
# 	//var homepage = getURL();
#
#
# $(".load").tooltip();
#
#
# 	$("#viewlagego").on('click', function(event) {
# 		search2();
#
# 	});
#
#
# });
#
#
#
#
# $(document).ready(function(){
#
#
#
# 		//$(".largecate").html($(".active a").html()+" >");
#
# 		function layer_open99(el){
# 		//$('.layer').addClass('open');
# 		$('.layer99').fadeIn();
# 		var temp = $('#' + el);
# 		if (temp.outerHeight() < $(document).height() ) temp.css('margin-top', '-'+temp.outerHeight()/2+'px');
# 		else temp.css('top', '0px');
# 		if (temp.outerWidth() < $(document).width() ) temp.css('margin-left', '-'+temp.outerWidth()/2+'px');
# 		else temp.css('left', '0px');
# 	}
#
# 	//	layer_open99('layer199'); /* 열고자 하는 것의 아이디를 입력 */
#
# 	$('.layer99 .bg99').click(function(){
# 		//$('.layer99').fadeOut();
# 	});
# 	$('#layer_close99').click(function(){
# 		$('.layer99').fadeOut();
# 		return false;
# 	});
#
#
#
# 	});
#
#
#
#
# //-->
# </script>
# </map></img></div></div></li></li></li></li></li></li></li></li></div></li></ol></div></div></div></div></div></div></div></div></div></div></div></body></head></html>

# %%
lis = search_result.find_all('li')[2:]
for li in lis:
    divs = li.find_all('div')
    
    #div[0]
    title = divs[0].a.text #상호
    spans = divs[0].find_all('span')
    search = spans[1].text #검색어
    
    #div[1]
    spans = divs[1].find_all('span')
    phone = spans[0].text #전화번호
    addr = spans[1].text #주소
    print(spans[2])
    print("%s %s %s %s"%(title, search, phone, addr))
# Out:
# <span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 명동길 55</span></span>
# 중정한의원 휴일진료병원 02-3789-7017 서울 중구 명동1가 7-1
# <span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 세종대로21길 53</span></span>
# 신농백초한의원 휴일진료병원 02-736-4644 서울 중구 정동 1-48
# <span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 </span></span>
# 서울백병원 휴일진료병원 02-2270-0119 서울 중구 저동 2가 85
# <span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 </span></span>
# 서울내과의원 휴일진료병원 02-2256-7575 서울 중구 신당6동 294-13
# <span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 </span></span>
# 반도병원 휴일진료병원 02-2252-0202 서울 중구 신당2동 422-4
# <span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 다산로 245</span></span>
# 하버드마취통증의학과의원 휴일진료병원 02-2236-8188 서울 중구 무학동 1
# <span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 </span></span>
# 청구경희한의원 휴일진료병원 02-2236-1075 서울 중구 신당4동 309-8
# <span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 </span></span>
# 유태석내과의원 휴일진료병원 02-2233-7076 서울 중구 신당3동 373-3
# <span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 퇴계로 115</span></span>
# 명동밀리오레산부인과의원 휴일진료병원 02-2124-0330 서울 중구 충무로1가 24-1
# <span class="load2"><img src="/image/loadi.png"/><span class="loadv"> 서울 중구 동호로 249</span></span>
# 장충동자생한의원 휴일진료병원 02-2234-0700 서울 중구 장충동2가 202
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-9b8f2f24750e> in <module>()
#       6     title = divs[0].a.text #상호
#       7     spans = divs[0].find_all('span')
# ----> 8     search = spans[1].text #검색어
#       9
#      10     #div[1]
#
# IndexError: list index out of range

# %% [markdown]
# ---
#
# ## selenium으로 플러그인 실행등이 필요한 정보에도 접근
# - phantomjs도 있다

# %%
#기본설정 - phantomjs는 실행경로를 지정해야한다. 윈도우와 리눅스계열이 조금 상이하므로 운영체제에 따라 경로를 잘 작성하자
# *이 코드는 윈도우 아나콘다용으로 작성됨*

from selenium import webdriver

url = 'http://www.smbs.biz/ExRate/TodayExRate.jsp'

phantomjs_path = r"C:\Users\creal\Anaconda3\pkgs\phantomjs-2.1.1-0\Library\bin\phantomjs.exe"
driver = webdriver.PhantomJS(executable_path = phantomjs_path)
driver.get(url)

print(driver.page_source[:1000])
# Out:
# C:\Users\creal\Anaconda3\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# <html lang="ko"><head><meta http-equiv="X-UA-Compatible" content="IE=edge"> <!-- LKJ_2016.12.05 -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!-- json calendar start -->
#
#
# <!-- json calendar e n d -->
#
#
# 	<meta http-equiv="Content-Type" content="text/html; charset=euc-kr">
# 	<meta http-equiv="Content-Script-Type" content="text/javascript">
# 	<meta http-equiv="Content-Style-Type" content="text/css">
# 	<meta name="description" content="">
# 	<meta name="keywords" content="">
# 	<title>서울외국환중개(주)에 오신것을 환영합니다.</title>
#
# 	<style>
#
#
# /*-------------------------------------------------------------------
# Basic Browsers (for IE 9(6,7,8), chrome, FF, safari)
# version: HTML 4.01, CSS2
# author: Kim ik joong
# email: kuerrilla@yahoo.co.kr
# website: webcodi.hosting.paran.com
# --------------------------------------------------------------------*/
#
# /*
# 	wrap
# ------------------------------------------------------------------- */
# #wrap{}
# #header{width:1091px; height:84px; margin:0 auto; z-index:20}
# #header h1{position:absolute; top:0; left

# %%
#Xpath 읽기!

krw_usd = driver.find_element_by_xpath('//*[@id="content"]/div[4]/table/tbody/tr[1]/td[2]')
krw_usd.text
# Out:
# '1,081.30'

# %%
from selenium import webdriver

url = 'http://www.naver.com'
driver = webdriver.PhantomJS(executable_path = phantomjs_path)
driver.get(url)

login_id = driver.find_element_by_name('id')
login_id.send_keys('uziminigun')#사용자의 ID

login_pw = driver.find_element_by_name('pw')
login_pw = send_keys('3579kmwO')#사용자의 PW

form = driver.find_element_by_id('frmNIDLogin')
form.submit()
# Out:
# C:\Users\creal\Anaconda3\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-5ac46d47f7cf> in <module>()
#       9
#      10 login_pw = driver.find_element_by_name('pw')
# ---> 11 login_pw = send_keys('3579kmwO')#사용자의 PW
#      12
#      13 form = driver.find_element_by_id('frmNIDLogin')
#
# NameError: name 'send_keys' is not defined

# %%
driver.save_screenshot('screenshot.png')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

url = 'http://www.smbs.biz/ExRate/TodayExRate.jsp'
phantomjs_path = r"C:\Users\creal\Anaconda3\pkgs\phantomjs-2.1.1-0\Library\bin\phantomjs.exe"
driver = webdriver.PhantomJS(executable_path = phantomjs_path)
driver.get(url)

soup = BeautifulSoup(driver.page_source, "lxml-xml")
tables = soup.find_all('table')
len(tables)
# Out:
# C:\Users\creal\Anaconda3\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# 3

# %%
tables[1]
# Out:
# <table summary="&lt;script&gt;d5( '%u_Db9e4%u_Db9e4%u_Dae30%u_Dc900%u_Dc728%u_Dd45c' );&lt;/script&gt;">
# <caption>매매기준율표(통화명/환율(원)/전일대비)</caption>
# <colgroup>
# <col style="width:236px">
# <col style="width:236px">
# <col style="width:*">
# </col>
# <thead>
# <tr>
# <th scope="col"><script>d1( '%u_Zd1b5%u_Zd654%u_Zba85' );</script>통화명</th>
# <th scope="col"><script>d2( '%u_Ad658%u_Ac728%_A28%u_Ac6d0%_A29' );</script>환율(원)</th>
# <th class="brr0" scope="col"><script>d3( '%u_Bc804%u_Bc77c%u_Bb300%u_Bbe44' );</script>전일대비</th>
# </tr>
# </thead>
# <tbody>
# <tr class="">
# <td class=""><script>d4( '%u_Cbbf8%_C20%u_Cb2ec%u_Cb7ec%u_Cd654%_C20%_C28%_C55%_C53%_C44%_C29' );</script>미 달러화 (USD)</td>
# <td class=""><script>d5( '%_D31%_D2c%_D30%_D38%_D31%_D2e%_D33%_D30' );</script>1,081.30</td>
# <td class="won_box vam tc brr0 ">
# <span class="txt_point"><script>d3( '%_B35%_B2e%_B32%_B30' );</script>5.20<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# </td>
# <tr class="brb0">
# <td class="brb0">위안화 (CNH)</td>
# <td class="brb0"><script>d5( '%_D31%_D36%_D38%_D2e%_D32%_D37' );</script>168.27</td>
# <td class="won_box vam tc brr0 brb0">
# <span class="txt_point"><script>d3( '%_B30%_B2e%_B33%_B31' );</script>0.31<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# </td>
# </tr>
# </tr>
# </tbody>
# <!-- //table -->
# <div class="hsec_type2 inquiry_h2"><h4 class="tit"><span class="ico ico_circle"><img alt="재정된 매매기준율 아이콘" src="../images/common/ico_o.gif" style="vertical-align:top;"/><script>d5( '%u_Dc7ac%u_Dc815%u_Db41c%_D20%u_Db9e4%u_Db9e4%u_Dae30%u_Dc900%u_Dc728' );</script>재정된 매매기준율</span></h4>
# <!-- //h -->
# <p class="p_txt_box2"><script>d1( '%u_Zc77c%u_Zbcf8%_Z20%u_Zc5d4%u_Zd654%_Z20%u_Zb4f1%_Z20%_Z34%_Z31%u_Zac1c%_Z20%u_Zd1b5%u_Zd654%u_Zc758%_Z20%u_Zc7ac%u_Zc815%u_Zb41c%_Z20%u_Zb9e4%u_Zb9e4%u_Zae30%u_Zc900%u_Zc728%u_Zc740%_Z20%u_Zcd5c%u_Zadfc%_Z20%u_Zc8fc%u_Zc694%_Z20%u_Zad6d%u_Zc81c%u_Zae08%u_Zc735%u_Zc2dc%u_Zc7a5%u_Zc5d0%u_Zc11c%_Z20%u_Zd615%u_Zc131%u_Zb41c%_Z20%u_Zbbf8%_Z20%u_Zb2ec%u_Zb7ec%u_Zd654%u_Zc640%_Z20%_Z20%u_Zae30%u_Zd0c0%_Z20%u_Zd1b5%u_Zd654%u_Zac04%u_Zc758%_Z20%u_Zb9e4%u_Zb9e4%u_Zc911%u_Zac04%u_Zc728%u_Zc744%_Z20%u_Zb9e4%u_Zb9e4%u_Zae30%u_Zc900%u_Zc728%u_Zb85c%_Z20%u_Zc7ac%u_Zc815%u_Zd558%u_Zc5ec%_Z20%u_Zc0b0%u_Zcd9c%u_Zd55c%_Z20%u_Zd658%u_Zc728%u_Zc744%_Z20%u_Zb9d0%u_Zd569%u_Zb2c8%u_Zb2e4%_Z2e' );</script>일본 엔화 등 41개 통화의 재정된 매매기준율은 최근 주요 국제금융시장에서 형성된 미 달러화와  기타 통화간의 매매중간율을 매매기준율로 재정하여 산출한 환율을 말합니다.</p>
# <div class="table_type7">
# <table summary="통화명/환율(원)/전일대비/Cross Rate">
# <caption>재정된 매매기준율</caption>
# <colgroup>
# <col style="width:*">
# <col style="width:157px">
# <col style="width:157px">
# <col style="width:107px">
# <col style="width:50px">
# </col>
# <thead>
# <tr>
# <th scope="col"><script>d2( '%u_Ad1b5%u_Ad654%u_Aba85' );</script>통화명</th>
# <th scope="col"><script>d3( '%u_Bd658%u_Bc728%_B28%u_Bc6d0%_B29' );</script>환율(원)</th>
# <th scope="col"><script>d4( '%u_Cc804%u_Cc77c%u_Cb300%u_Cbe44' );</script>전일대비</th>
# <th class="brr0" colspan="2" scope="col"><script>d5( '%_D43%_D72%_D6f%_D73%_D73%_D20%_D52%_D61%_D74%_D65' );</script>Cross Rate</th>
# </tr>
# </thead>
# <tbody>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zc77c%u_Zbcf8%_Z20%u_Zc5d4%u_Zd654%_Z20%_Z28%_Z4a%_Z50%_Z59%_Z29%_Z20%_Z28%_Z31%_Z30%_Z30%_Z29' );</script>일본 엔화 (JPY) (100)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A39%_A39%_A33%_A2e%_A39%_A38' );</script>993.98</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D32%_D2e%_D35%_D39%_D30%_D30%_D30' );</script>2.59000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z31%_Z30%_Z38%_Z2e%_Z37%_Z38%_Z35%_Z30%_Z30' );</script>108.78500</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zc720%u_Zb85c%u_Zd654%_Z20%_Z28%_Z45%_Z55%_Z52%_Z29' );</script>유로화 (EUR)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A31%_A2c%_A32%_A36%_A31%_A2e%_A33%_A34' );</script>1,261.34</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D31%_D39%_D2e%_D31%_D34%_D30%_D30%_D30' );</script>19.14000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z31%_Z2e%_Z31%_Z36%_Z36%_Z35%_Z30' );</script>1.16650</span></td>
# <td class="won_box brr0"><span class="won3"> <script>d1( '%_Z28%_Z55%_Z53%_Z24%_Z29' );</script>(US$) </span></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zc601%u_Zad6d%_Z20%u_Zd30c%u_Zc6b4%u_Zb4dc%u_Zd654%_Z20%_Z28%_Z47%_Z42%_Z50%_Z29' );</script>영국 파운드화 (GBP)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A31%_A2c%_A34%_A33%_A36%_A2e%_A35%_A31' );</script>1,436.51</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D39%_D2e%_D36%_D36%_D30%_D30%_D30' );</script>9.66000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z31%_Z2e%_Z33%_Z32%_Z38%_Z35%_Z30' );</script>1.32850</span></td>
# <td class="won_box brr0"><span class="won3"> <script>d1( '%_Z28%_Z55%_Z53%_Z24%_Z29' );</script>(US$) </span></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zce90%u_Zb098%u_Zb2e4%_Z20%u_Zb2ec%u_Zb7ec%u_Zd654%_Z20%_Z28%_Z43%_Z41%_Z44%_Z29' );</script>캐나다 달러화 (CAD)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A38%_A33%_A38%_A2e%_A38%_A30' );</script>838.80</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D31%_D32%_D2e%_D32%_D37%_D30%_D30%_D30' );</script>12.27000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z31%_Z2e%_Z32%_Z38%_Z39%_Z31%_Z30' );</script>1.28910</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zc2a4%u_Zc704%u_Zc2a4%_Z20%u_Zd504%u_Zb791%u_Zd654%_Z20%_Z28%_Z43%_Z48%_Z46%_Z29' );</script>스위스 프랑화 (CHF)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A31%_A2c%_A30%_A39%_A33%_A2e%_A31%_A31' );</script>1,093.11</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D37%_D2e%_D31%_D38%_D30%_D30%_D30' );</script>7.18000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z30%_Z2e%_Z39%_Z38%_Z39%_Z32%_Z30' );</script>0.98920</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zd638%u_Zc8fc%_Z20%u_Zb2ec%u_Zb7ec%u_Zd654%_Z20%_Z28%_Z41%_Z55%_Z44%_Z29' );</script>호주 달러화 (AUD)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A38%_A31%_A38%_A2e%_A39%_A32' );</script>818.92</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D31%_D31%_D2e%_D34%_D37%_D30%_D30%_D30' );</script>11.47000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z30%_Z2e%_Z37%_Z35%_Z37%_Z33%_Z35' );</script>0.75735</span></td>
# <td class="won_box brr0"><span class="won3"> <script>d1( '%_Z28%_Z55%_Z53%_Z24%_Z29' );</script>(US$) </span></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zb274%u_Zc9c8%u_Zb79c%u_Zb4dc%_Z20%u_Zb2ec%u_Zb7ec%u_Zd654%_Z20%_Z28%_Z4e%_Z5a%_Z44%_Z29' );</script>뉴질랜드 달러화 (NZD)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A37%_A35%_A35%_A2e%_A31%_A38' );</script>755.18</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D31%_D32%_D2e%_D37%_D38%_D30%_D30%_D30' );</script>12.78000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z30%_Z2e%_Z36%_Z39%_Z38%_Z34%_Z30' );</script>0.69840</span></td>
# <td class="won_box brr0"><span class="won3"> <script>d1( '%_Z28%_Z55%_Z53%_Z24%_Z29' );</script>(US$) </span></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zd64d%u_Zcf69%_Z20%u_Zb2ec%u_Zb7ec%u_Zd654%_Z20%_Z28%_Z48%_Z4b%_Z44%_Z29' );</script>홍콩 달러화 (HKD)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A31%_A33%_A37%_A2e%_A37%_A39' );</script>137.79</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D36%_D33%_D30%_D30%_D30' );</script>0.63000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z37%_Z2e%_Z38%_Z34%_Z37%_Z33%_Z30' );</script>7.84730</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zb300%u_Zb9cc%_Z20%u_Zb2ec%u_Zb7ec%u_Zd654%_Z20%_Z28%_Z54%_Z57%_Z44%_Z29' );</script>대만 달러화 (TWD)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A33%_A36%_A2e%_A31%_A35' );</script>36.15</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D33%_D35%_D30%_D30%_D30' );</script>0.35000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z32%_Z39%_Z2e%_Z39%_Z31%_Z31%_Z30%_Z30' );</script>29.91100</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zbabd%u_Zace8%_Z20%u_Zd22c%u_Zadf8%u_Zb9ad%u_Zd654%_Z20%_Z28%_Z4d%_Z4e%_Z54%_Z29' );</script>몽골 투그릭화 (MNT)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A30%_A2e%_A34%_A35' );</script>0.45</span></td>
# <td class="won_box vam">
# <span class="won2"><script>d4( '%_C30' );</script>0</span>
# </td>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z32%_Z2c%_Z34%_Z31%_Z30%_Z2e%_Z30%_Z30%_Z30%_Z30%_Z30' );</script>2,410.00000</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </tr>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zce74%u_Zc790%u_Zd750%u_Zc2a4%u_Zd0c4%_Z20%u_Zd161%u_Zac8c%u_Zd654%_Z20%_Z28%_Z4b%_Z5a%_Z54%_Z29' );</script>카자흐스탄 텡게화 (KZT)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A33%_A2e%_A32%_A38' );</script>3.28</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D30%_D32%_D30%_D30%_D30' );</script>0.02000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z33%_Z33%_Z30%_Z2e%_Z31%_Z30%_Z35%_Z30%_Z30' );</script>330.10500</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zd0dc%u_Zad6d%_Z20%u_Zbc27%u_Zd654%_Z20%_Z28%_Z54%_Z48%_Z42%_Z29' );</script>태국 밧화 (THB)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A33%_A33%_A2e%_A37%_A35' );</script>33.75</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D32%_D32%_D30%_D30%_D30' );</script>0.22000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z33%_Z32%_Z2e%_Z30%_Z33%_Z35%_Z30%_Z30' );</script>32.03500</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zc2f1%u_Zac00%u_Zd3ec%u_Zb974%_Z20%u_Zb2ec%u_Zb7ec%u_Zd654%_Z20%_Z28%_Z53%_Z47%_Z44%_Z29' );</script>싱가포르 달러화 (SGD)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A38%_A30%_A37%_A2e%_A35%_A31' );</script>807.51</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D38%_D2e%_D30%_D36%_D30%_D30%_D30' );</script>8.06000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z31%_Z2e%_Z33%_Z33%_Z39%_Z30%_Z35' );</script>1.33905</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zc778%u_Zb3c4%u_Zb124%u_Zc2dc%u_Zc544%_Z20%u_Zb8e8%u_Zd53c%u_Zc544%u_Zd654%_Z20%_Z28%_Z49%_Z44%_Z52%_Z29%_Z20%_Z28%_Z31%_Z30%_Z30%_Z29' );</script>인도네시아 루피아화 (IDR) (100)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A37%_A2e%_A37%_A33' );</script>7.73</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D30%_D34%_D30%_D30%_D30' );</script>0.04000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z31%_Z33%_Z2c%_Z39%_Z39%_Z30%_Z2e%_Z30%_Z30%_Z30%_Z30%_Z30' );</script>13,990.00000</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zb9d0%u_Zb808%u_Zc774%u_Zc2dc%u_Zc544%_Z20%u_Zb9c1%u_Zae43%u_Zd654%_Z20%_Z28%_Z4d%_Z59%_Z52%_Z29' );</script>말레이시아 링깃화 (MYR)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A32%_A37%_A31%_A2e%_A31%_A30' );</script>271.10</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D38%_D39%_D30%_D30%_D30' );</script>0.89000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z33%_Z2e%_Z39%_Z38%_Z38%_Z35%_Z30' );</script>3.98850</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zd544%u_Zb9ac%u_Zd540%_Z20%u_Zd398%u_Zc18c%u_Zd654%_Z20%_Z28%_Z50%_Z48%_Z50%_Z29' );</script>필리핀 페소화 (PHP)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A32%_A30%_A2e%_A35%_A38' );</script>20.58</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D31%_D36%_D30%_D30%_D30' );</script>0.16000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z35%_Z32%_Z2e%_Z35%_Z34%_Z31%_Z35%_Z30' );</script>52.54150</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zbca0%u_Zd2b8%u_Zb0a8%_Z20%u_Zb3d9%u_Zd654%_Z20%_Z28%_Z56%_Z4e%_Z44%_Z29%_Z20%_Z28%_Z31%_Z30%_Z30%_Z29' );</script>베트남 동화 (VND) (100)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A34%_A2e%_A37%_A33' );</script>4.73</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D30%_D32%_D30%_D30%_D30' );</script>0.02000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z32%_Z32%_Z2c%_Z38%_Z35%_Z35%_Z2e%_Z30%_Z30%_Z30%_Z30%_Z30' );</script>22,855.00000</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zbe0c%u_Zb8e8%u_Zb098%u_Zc774%_Z20%u_Zb2ec%u_Zb7ec%u_Zd654%_Z20%_Z28%_Z42%_Z4e%_Z44%_Z29' );</script>브루나이 달러화 (BND)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A38%_A31%_A31%_A2e%_A34%_A35' );</script>811.45</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D37%_D2e%_D31%_D33%_D30%_D30%_D30' );</script>7.13000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z31%_Z2e%_Z33%_Z33%_Z32%_Z35%_Z35' );</script>1.33255</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zc778%u_Zb3c4%_Z20%u_Zb8e8%u_Zd53c%u_Zd654%_Z20%_Z28%_Z49%_Z4e%_Z52%_Z29' );</script>인도 루피화 (INR)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A31%_A36%_A2e%_A30%_A33' );</script>16.03</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D31%_D37%_D30%_D30%_D30' );</script>0.17000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z36%_Z37%_Z2e%_Z34%_Z34%_Z30%_Z30%_Z30' );</script>67.44000</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zd30c%u_Zd0a4%u_Zc2a4%u_Zd0c4%_Z20%u_Zb8e8%u_Zd53c%u_Zd654%_Z20%_Z28%_Z50%_Z4b%_Z52%_Z29' );</script>파키스탄 루피화 (PKR)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A39%_A2e%_A33%_A34' );</script>9.34</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D30%_D35%_D30%_D30%_D30' );</script>0.05000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z31%_Z31%_Z35%_Z2e%_Z37%_Z37%_Z35%_Z30%_Z30' );</script>115.77500</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zbc29%u_Zae00%u_Zb77c%u_Zb370%u_Zc2dc%_Z20%u_Zd0c0%u_Zce74%u_Zd654%_Z20%_Z28%_Z42%_Z44%_Z54%_Z29' );</script>방글라데시 타카화 (BDT)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A31%_A32%_A2e%_A38%_A30' );</script>12.80</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D30%_D37%_D30%_D30%_D30' );</script>0.07000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z38%_Z34%_Z2e%_Z35%_Z30%_Z30%_Z30%_Z30' );</script>84.50000</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zba55%u_Zc2dc%u_Zcf54%_Z20%u_Zd398%u_Zc18c%u_Zd654%_Z20%_Z28%_Z4d%_Z58%_Z4e%_Z29' );</script>멕시코 페소화 (MXN)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A35%_A34%_A2e%_A36%_A33' );</script>54.63</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D33%_D32%_D30%_D30%_D30' );</script>0.32000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z31%_Z39%_Z2e%_Z37%_Z39%_Z33%_Z35%_Z30' );</script>19.79350</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zbe0c%u_Zb77c%u_Zc9c8%_Z20%u_Zd5e4%u_Zc54c%u_Zd654%_Z20%_Z28%_Z42%_Z52%_Z4c%_Z29' );</script>브라질 헤알화 (BRL)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A32%_A39%_A30%_A2e%_A33%_A38' );</script>290.38</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D31%_D2e%_D35%_D35%_D30%_D30%_D30' );</script>1.55000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z33%_Z2e%_Z37%_Z32%_Z33%_Z37%_Z30' );</script>3.72370</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zc544%u_Zb974%u_Zd5e8%u_Zd2f0%u_Zb098%_Z20%u_Zd398%u_Zc18c%u_Zd654%_Z20%_Z28%_Z41%_Z52%_Z53%_Z29' );</script>아르헨티나 페소화 (ARS)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A34%_A33%_A2e%_A33%_A38' );</script>43.38</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D30%_D39%_D30%_D30%_D30' );</script>0.09000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z32%_Z34%_Z2e%_Z39%_Z32%_Z35%_Z30%_Z30' );</script>24.92500</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zc2a4%u_Zc6e8%u_Zb374%_Z20%u_Zd06c%u_Zb85c%u_Zb098%u_Zd654%_Z20%_Z28%_Z53%_Z45%_Z4b%_Z29' );</script>스웨덴 크로나화 (SEK)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A31%_A32%_A32%_A2e%_A37%_A38' );</script>122.78</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D32%_D2e%_D36%_D38%_D30%_D30%_D30' );</script>2.68000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z38%_Z2e%_Z38%_Z30%_Z36%_Z37%_Z35' );</script>8.80675</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zb374%u_Zb9c8%u_Zd06c%_Z20%u_Zd06c%u_Zb85c%u_Zb124%u_Zd654%_Z20%_Z28%_Z44%_Z4b%_Z4b%_Z29' );</script>덴마크 크로네화 (DKK)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A31%_A36%_A39%_A2e%_A34%_A39' );</script>169.49</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D32%_D2e%_D35%_D37%_D30%_D30%_D30' );</script>2.57000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z36%_Z2e%_Z33%_Z37%_Z39%_Z39%_Z30' );</script>6.37990</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zb178%u_Zb974%u_Zc6e8%u_Zc774%_Z20%u_Zd06c%u_Zb85c%u_Zb124%u_Zd654%_Z20%_Z28%_Z4e%_Z4f%_Z4b%_Z29' );</script>노르웨이 크로네화 (NOK)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A31%_A33%_A32%_A2e%_A31%_A34' );</script>132.14</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D32%_D2e%_D32%_D39%_D30%_D30%_D30' );</script>2.29000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z38%_Z2e%_Z31%_Z38%_Z33%_Z30%_Z35' );</script>8.18305</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zb7ec%u_Zc2dc%u_Zc544%_Z20%u_Zb8e8%u_Zbe14%u_Zd654%_Z20%_Z28%_Z52%_Z55%_Z42%_Z29' );</script>러시아 루블화 (RUB)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A31%_A37%_A2e%_A34%_A31' );</script>17.41</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D32%_D39%_D30%_D30%_D30' );</script>0.29000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z36%_Z32%_Z2e%_Z31%_Z30%_Z32%_Z32%_Z30' );</script>62.10220</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zd5dd%u_Zac00%u_Zb9ac%_Z20%u_Zd3ec%u_Zb9b0%u_Zd2b8%u_Zd654%_Z20%_Z28%_Z48%_Z55%_Z46%_Z29' );</script>헝가리 포린트화 (HUF)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A33%_A2e%_A39%_A35' );</script>3.95</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D30%_D38%_D30%_D30%_D30' );</script>0.08000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z32%_Z37%_Z34%_Z2e%_Z30%_Z37%_Z30%_Z30%_Z30' );</script>274.07000</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zd3f4%u_Zb780%u_Zb4dc%_Z20%u_Zc988%u_Zc6cc%u_Zd2f0%u_Zd654%_Z20%_Z28%_Z50%_Z4c%_Z4e%_Z29' );</script>폴란드 즈워티화 (PLN)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A32%_A39%_A32%_A2e%_A39%_A34' );</script>292.94</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D36%_D2e%_D33%_D35%_D30%_D30%_D30' );</script>6.35000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z33%_Z2e%_Z36%_Z39%_Z31%_Z31%_Z35' );</script>3.69115</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zccb4%u_Zcf54%_Z20%u_Zcf54%u_Zb8e8%u_Zb098%u_Zd654%_Z20%_Z28%_Z43%_Z5a%_Z4b%_Z29' );</script>체코 코루나화 (CZK)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A34%_A38%_A2e%_A37%_A39' );</script>48.79</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D39%_D30%_D30%_D30%_D30' );</script>0.90000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z32%_Z32%_Z2e%_Z31%_Z36%_Z32%_Z35%_Z30' );</script>22.16250</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zc0ac%u_Zc6b0%u_Zb514%u_Zc544%u_Zb77c%u_Zbe44%u_Zc544%_Z20%u_Zb9ac%u_Zc584%u_Zd654%_Z20%_Z28%_Z53%_Z41%_Z52%_Z29' );</script>사우디아라비아 리얄화 (SAR)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A32%_A38%_A38%_A2e%_A33%_A32' );</script>288.32</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D31%_D2e%_D33%_D39%_D30%_D30%_D30' );</script>1.39000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z33%_Z2e%_Z37%_Z35%_Z30%_Z33%_Z35' );</script>3.75035</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zce74%u_Zd0c0%u_Zb974%_Z20%u_Zb9ac%u_Zc584%u_Zd654%_Z20%_Z28%_Z51%_Z41%_Z52%_Z29' );</script>카타르 리얄화 (QAR)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A32%_A39%_A36%_A2e%_A39%_A38' );</script>296.98</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D31%_D2e%_D34%_D33%_D30%_D30%_D30' );</script>1.43000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z33%_Z2e%_Z36%_Z34%_Z31%_Z30%_Z30' );</script>3.64100</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zc774%u_Zc2a4%u_Zb77c%u_Zc5d8%_Z20%u_Zc170%u_Zcf08%u_Zd654%_Z20%_Z28%_Z49%_Z4c%_Z53%_Z29' );</script>이스라엘 셰켈화 (ILS)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A33%_A30%_A32%_A2e%_A39%_A31' );</script>302.91</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D33%_D2e%_D33%_D39%_D30%_D30%_D30' );</script>3.39000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z33%_Z2e%_Z35%_Z36%_Z39%_Z37%_Z30' );</script>3.56970</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zc694%u_Zb974%u_Zb2e8%_Z20%u_Zb514%u_Zb098%u_Zb974%u_Zd654%_Z20%_Z28%_Z4a%_Z4f%_Z44%_Z29' );</script>요르단 디나르화 (JOD)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A31%_A2c%_A35%_A32%_A34%_A2e%_A30%_A33' );</script>1,524.03</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D37%_D2e%_D33%_D33%_D30%_D30%_D30' );</script>7.33000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z30%_Z2e%_Z37%_Z30%_Z39%_Z35%_Z30' );</script>0.70950</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zcfe0%u_Zc6e8%u_Zc774%u_Zd2b8%_Z20%u_Zb514%u_Zb098%u_Zb974%u_Zd654%_Z20%_Z28%_Z4b%_Z57%_Z44%_Z29' );</script>쿠웨이트 디나르화 (KWD)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A33%_A2c%_A35%_A37%_A35%_A2e%_A37%_A33' );</script>3,575.73</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D31%_D37%_D2e%_D35%_D35%_D30%_D30%_D30' );</script>17.55000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z30%_Z2e%_Z33%_Z30%_Z32%_Z34%_Z30' );</script>0.30240</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zbc14%u_Zb808%u_Zc778%_Z20%u_Zb514%u_Zb098%u_Zb974%u_Zd654%_Z20%_Z28%_Z42%_Z48%_Z44%_Z29' );</script>바레인 디나르화 (BHD)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A32%_A2c%_A38%_A36%_A33%_A2e%_A36%_A31' );</script>2,863.61</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D31%_D34%_D2e%_D31%_D35%_D30%_D30%_D30' );</script>14.15000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z30%_Z2e%_Z33%_Z37%_Z37%_Z36%_Z30' );</script>0.37760</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zc544%u_Zb78d%u_Zc5d0%u_Zbbf8%u_Zb9ac%u_Zd2b8%_Z20%u_Zb514%u_Zb974%u_Zd568%u_Zd654%_Z20%_Z28%_Z41%_Z45%_Z44%_Z29' );</script>아랍에미리트 디르함화 (AED)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A32%_A39%_A34%_A2e%_A33%_A38' );</script>294.38</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D31%_D2e%_D34%_D32%_D30%_D30%_D30' );</script>1.42000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z33%_Z2e%_Z36%_Z37%_Z33%_Z31%_Z35' );</script>3.67315</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zd130%u_Zd0a4%_Z20%u_Zb9ac%u_Zb77c%u_Zd654%_Z20%_Z28%_Z54%_Z52%_Z59%_Z29' );</script>터키 리라화 (TRY)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A32%_A34%_A32%_A2e%_A33%_A39' );</script>242.39</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D36%_D2e%_D33%_D36%_D30%_D30%_D30' );</script>6.36000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z34%_Z2e%_Z34%_Z36%_Z31%_Z30%_Z30' );</script>4.46100</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right">
# <td class="tl"><script>d1( '%u_Zb0a8%u_Zc544%u_Zd504%u_Zb9ac%u_Zce74%u_Zacf5%u_Zd654%u_Zad6d%_Z20%u_Zb79c%u_Zb4dc%u_Zd654%_Z20%_Z28%_Z5a%_Z41%_Z52%_Z29' );</script>남아프리카공화국 랜드화 (ZAR)</td>
# <td class="won_box"><span class="won"><script>d2( '%_A38%_A36%_A2e%_A33%_A30' );</script>86.30</span></td>
# <td class="won_box vam">
# <span class="won2 txt_point"><script>d5( '%_D31%_D2e%_D35%_D31%_D30%_D30%_D30' );</script>1.51000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0"><span class="won3"><script>d1( '%_Z31%_Z32%_Z2e%_Z35%_Z33%_Z30%_Z32%_Z30' );</script>12.53020</span></td>
# <td class="won_box brr0"><span class="won3"/></td>
# </td>
# <tr align="right" class="brb0">
# <td class="tl brb0"><script>d1( '%u_Zc774%u_Zc9d1%u_Zd2b8%_Z20%u_Zd30c%u_Zc6b4%u_Zb4dc%u_Zd654%_Z20%_Z28%_Z45%_Z47%_Z50%_Z29' );</script>이집트 파운드화 (EGP)</td>
# <td class="won_box brb0"><span class="won"><script>d2( '%_A36%_A30%_A2e%_A33%_A34' );</script>60.34</span></td>
# <td class="won_box vam brb0">
# <span class="won2 txt_point"><script>d5( '%_D30%_D2e%_D32%_D39%_D30%_D30%_D30' );</script>0.29000<span class="ico ico_up"><img alt="환율상승 아이콘" src="../images/common/ico_up.png" style="vertical-align:top;"/></span>
# </span>
# <td class="won_box brr0 brb0"><span class="won3"><script>d1( '%_Z31%_Z37%_Z2e%_Z39%_Z32%_Z30%_Z30%_Z30' );</script>17.92000</span></td>
# <td class="won_box brr0 brb0"><span class="won3"/></td>
# </td>
# </tr>
# </tr>
# </tr>
# <p class="p_txt_box3" id="bottomMent">
# <span class="ico ico_feel2"><img alt="느낌표 아이콘 이미지" src="../images/common/ico_i.gif"/><span class="txt">홈페이지상에서 조회하여 출력한 환율정보가 시스템의 장애 등으로 잘못 출력된 경우 서울외국환중개가 책임지지 않습니다.</span>
# </span>
# <!-- //table -->
# <p class="btn_area">
# <a href="Javascript:doPrint();"><img alt="인쇄하기 버튼 이미지" src="../images/common/btn_print.gif"/><a href="Javascript:getExcelData( 'frm_SearchDate' )">;=""&gt;<img alt="엑셀다운로드 버튼 이미지" src="../images/common/btn_down.gif"/>
# </a>
# <!-- //btn -->
# <!-- CNY 고시 중단 고지 팝업 추가 LKJ_2016.12.05 _ (start) -->
# <div id="main_popup" style="position: absolute; z-index: 1; padding: 76.70681377545675px 0px 0px; top: 0px; width: 179.85990204071152px; height: 399.7905477787302px; overflow: hidden; background-color: rgba(0, 0, 0, 0.2); margin: 0px; opacity: 0.2522706657837962;">
# <div style="position: relative; background-color: #fefefe; margin: auto; padding: 0; border: 2px solid #7a0303; width: 80%; box-shadow: 0 4px 8px 0 rgba(0,0,0,0.2),0 6px 20px 0 rgba(0,0,0,0.19); -webkit-animation-name: animatetop; -webkit-animation-duration: 0.4s; animation-name: animatetop; animation-duration: 0.4s">
# <div class="hsec_type2 customer_h3" style="padding:6px"><h4 class="tit"><span class="ico ico_circle"/>재공지</h4></div>
# <div style="border-top:2px solid #9c002c;"/>
# <div style="margin:1px 10px">
# <strong style="font-size: 14px;color:black">CNY는 2016년 1월 1일부터 고시하지 않습니다.<br><br>CNY 환율 및 적용관련 문의는 거래하시는 금융기관에 문의하시기 바랍니다.</br>
# <br><br>
# <strong style="float:right;font-size: 12px;"><a href="http://www.smbs.biz/Customer/NoticeRead.jsp?PageNo=1&amp;idx=60&amp;StrSchOpt=T&amp;StrSchTxt=">[상세보기]</a></strong>
# <br>
# </br>
# <button onclick="closePopupNotToday();" style="background-color: #ffffff;border: 1px solid #9c002c;color: black;padding: 4px 15px;border-radius: 8px;text-align: center;text-decoration: none;display: inline-block;font-size: 13px;margin: 4px 2px;cursor: pointer;float:right;margin: 2px;" type="button">30일간 열지 않음</button>
# <button onclick="closeMainPopup();" style="background-color: #ffffff;border: 1px solid #9c002c;color: black;padding: 4px 15px;border-radius: 8px;text-align: center;text-decoration: none;display: inline-block;font-size: 13px;margin: 4px 2px;cursor: pointer;float:right;margin: 2px;" type="button">닫기</button>
# </br>
# </br>
# <!-- CNY 고시 중단 고지 팝업 추가 LKJ_2016.12.05 _ (end) -->
# <!-- //내용 -->
# <!-- LoadingBar -->
# </br>
# </strong>
# <div class="quickmenu">
# <ul>
# <li><a href="/ExRate/TodayExRate.jsp"><img alt="오늘의 환율 버튼 이미지" src="../images/@temp/quick_today.png"/></a>
# <li><a href="/ExRate/StdExRate.jsp"><img alt="기간별 매매기준율 버튼 이미지" src="../images/@temp/quick_trade.png"/></a>
# </li>
# <a href="Javascript:pop_center('/ExRatePop/ExRatePrint.jsp','720','840');"><img alt="환율출력 버튼 이미지" src="../images/@temp/quick_print.png"/>
# </a>
# </li>
# <hr>
# <div id="footer">
# <div class="box" style="padding-bottom:0px;">
# <p class="copy"><img alt="COPYRIGHT ⓒ 2011 SMBS,LTD.ALL RIGHT RESERVED" src="../images/common/footer_copy.png"/>
# <p class="logo"><img alt="서울외국환중개 로고 이미지" src="../images/common/footer_logo.gif"/>
# <div class="footer_nav">
# <ul>
# <!--<li><a href="/Customer/CusMain.jsp"><img src="../images/common/footer_btn2.gif" alt="고객센터 버튼 이미지"></a><span class="bar"></span></li>
# -->
# <li><a href="/Member/PersnalCompany.jsp"><img alt="개인정보처리방침(회사) 버튼 이미지" src="../images/common/footer_btn8.gif"/><span class="bar"/></a>
# <li><a href="/Member/Persnal.jsp"><img alt="개인정보처리방침(홈페이지) 버튼 이미지" src="../images/common/footer_btn3.gif"/><span class="bar"/></a>
# <li><a href="/Member/CreditInfo.jsp"><img alt="신용정보활용체제 버튼 이미지" src="../images/common/footer_btn9.gif"/><span class="bar"/></a>
# <li><a href="/Company/SettlementAnnouncement.jsp"><img alt="결산공고" src="../images/common/footer_btn10.gif"/><span class="bar"/></a>
# <li><a href="/Member/Email.jsp"><img alt="이메일무단수집거부 버튼 이미지 " src="../images/common/footer_btn4.gif"/><span class="bar"/></a>
# <li><a href="/Member/Policy.jsp"><img alt="이용약관 버튼 이미지" src="../images/common/footer_btn5.gif"/><span class="bar"/></a>
# <li><a href="/Company/ContactUS.jsp"><img alt="CONTACT US 버튼 이미지" src="../images/common/footer_btn6.gif"/><span class="bar"/></a>
# <li><a href="/Sitemap/Sitemap.jsp"><img alt="Site Map 버튼 이미지" src="../images/common/footer_btn7.gif"/></a>
# </li>
# <address><img alt="사업자등록번호 : 201-81-57726    대표이사 : 정희전    주소 : 서울특별시 중구 삼일대로 358 (을지로2가, 신한L타워 12~14층) (우)04542    통신판매업신고 : 2008-서울중구-0471호" src="../images/common/footer_add.gif"><a href="http://www.ftc.go.kr/info/bizinfo/communicationList.jsp?area1=&amp;area2=&amp;currpage=1&amp;searchKey=01&amp;searchVal=서울외국환중개&amp;stdate=&amp;enddate=" target="_blank"><img alt="사업자 정보확인 이미지" src="../images/common/button_check_ftc.png"/></a>
# <address><img alt="TEL : 02-6211-8000  FAX : 02-6211-8069" src="../images/common/footer_add2.jpg"/>
# </address>
# <!-- //nav -->
# </img>
# </address>
# <!-- //footer -->
# </li>
# <iframe frameborder="0" height="0" id="excel_doc" marginheight="0" marginwidth="0" name="excel_doc" scrolling="no" title="엑셀 테이블" width="0"/>
# <!-- <iframe src="print_doc.jsp" name="print_doc" id="print_doc" width="0" height="0" marginwidth="0" marginheight="0" scrolling="no" frameborder="0"></iframe> -->
# <iframe frameborder="0" height="0" id="print_flash" marginheight="0" marginwidth="0" name="print_flash" scrolling="no" title="플래시 대시보드" width="0"/>
# <!-- <iframe src="/Common/getDate.jsp" name="calendarIFrame" id="calendarIFrame" width="300" height="310" marginwidth="0" marginheight="0" scrolling="no" frameborder="3" style="display: none; position: absolute; top: 0px; left: 0px;"></iframe> -->
# <script>
# var copy_text;
# copy_text=content.innerHTML;
# var copy_titletext;
# copy_titletext=r_info_title.innerHTML;
# function CONTENT_PRINT(){
# 	print_doc.print_content.innerHTML = (copy_titletext+"<br><br>"+copy_text);
# 	print_doc.zoom_print();
# 	print_doc.focus();
# 	print_doc.print();
# }
# function flash_content_print(print_url){
# /*
# 	if(ui == "safari" || ui == "ie9" ){
# 	//if(ui == "safari" ){
# 		window.print();
# 		$('#progBar').hide();
# 	}else{
# 		$('#progBar',parent.document).show();
# 		var ori_url = document.getElementById("frm_SearchDate").action;
# 		document.getElementById("frm_SearchDate").action = print_url;
# 		document.getElementById("frm_SearchDate").target = "print_flash";
# 		//frm_SearchDate.target = "_blank";
# 		document.getElementById("frm_SearchDate").submit();
# 		document.getElementById("frm_SearchDate").action = ori_url;
# 		document.getElementById("frm_SearchDate").target = "";
# 	}
# */
# 	window.open( print_url, "_blank", "width=770px,height=800px,menubar=no,resizable=no,scrollbars=yes,status=no,titlebar=no,toolbar=no" );
# }
# </br>
# <!-- 구글 통계 -->
# <script type="text/javascript">
# 	var _gaq = _gaq || [];
# 	_gaq.push(['_setAccount', 'UA-27811871-1']);
# 	_gaq.push(['_trackPageview']);
# 	(function() {
# 		var ga = document.createElement('script');
# 		ga.type = 'text/javascript';
# 		ga.async = true;
# 		ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 		var s = document.getElementsByTagName('script')[0];
# 		s.parentNode.insertBefore(ga, s);
# 	})();
# </script>
# <!-- //구글 통계 -->
# <iframe border="0" frameborder="no" height="0" id="printAreaFrame" marginheight="0" marginwidth="0" name="printAreaFrame" title="구글통계 테이블" width="0"/>
# <!--
# <IFrame name="BannerForm" width="0" height="0" marginwidth="0" marginheight="0" frameborder="no" border="0" width="0" height="0"></IFrame>
# -->
# <iframe border="0" frameborder="no" height="0" marginheight="0" marginwidth="0" name="BannerForm" title="배너 테이블" width="0"/>
# </br></script></li></li></li></li></li></li></ul></div></p></p></div></div></hr></ul></div></div></div></div></a></p></p></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tbody></col></col></col></col></colgroup></table></div></div></col></col></colgroup></table>

# %%
import pandas as pd
dfs = pd.read_html(driver.page_source)
print(len(dfs))
df = dfs[1]
df
# Out:
# 3
#                 d1( '%u_Zd1b5%u_Zd654%u_Zba85' );통화명  \
# 0  d4( '%u_Cbbf8%_C20%u_Cb2ec%u_Cb7ec%u_Cd654%_C2...
# 1                                          위안화 (CNH)
#
#     d2( '%u_Ad658%u_Ac728%_A28%u_Ac6d0%_A29' );환율(원)  \
# 0  d5( '%_D31%_D2c%_D30%_D38%_D31%_D2e%_D33%_D30'...
# 1      d5( '%_D31%_D36%_D38%_D2e%_D32%_D37' );168.27
#
#   d3( '%u_Bc804%u_Bc77c%u_Bb300%u_Bbe44' );전일대비
# 0             d3( '%_B35%_B2e%_B32%_B30' );5.20
# 1             d3( '%_B30%_B2e%_B33%_B31' );0.31

# %%
#정규식을 사용하여 쓸데없는 문구와 특수문자 제거
df.columns = df.columns.str.replace('(d\d+\(.*\);)','')

for c in range(0, len(df.columns)):
    df.iloc[:, c] = df.iloc[:,c].str.replace('(d\d+\(.*\);)','')
    
df
# Out:
#            통화명     환율(원)  전일대비
# 0  미 달러화 (USD)  1,081.30  5.20
# 1    위안화 (CNH)    168.27  0.31
