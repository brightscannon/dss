# %% [markdown]
# # 취업자 특강
# > ### 목차
# - 데이터는 처절하고 어렵다. 흥미가 있어야 계속 할 수 있다.
# - 공부는 어떻게 계속 해야할까? -->
#     - 열심히.. 하는것 열심히 하자.
#     - 수학, 프로그래밍 다 손에 익고 말할 수 있어야.
#     - 끝나고 난뒤 --> 배움은 계속해야하나 다 완벽히 할 필요는 없다. 기본기를 확실히 쌓아가자고 생각
#     - 하고싶은 공부, 분석, 일 이 세가지 찾자
#
# >
# - 배운것은 데이터분석 활용하는 회사에서는 많이 쓰인다. 엄청나게 쓰인다.
# - 데이터 활용하는 회사를 리서치 할 필요가 있다. 잘 활용하는곳이 내가 잘 일할 수 있는 곳이지 않을까?
#
#
# #### - 수학이 중요한가? : 그렇다 (역량과 결과차이가 수학지식에서 난다)
#    - 예시 : 같은 프로젝트에 들어가면 똑같이 알더라도 더 좋은 결과를 도출한다. 세부적인걸 더 잘 알고있기때문에.
# - 좋은 프로젝트의 주제는? : 내가 관심있고 잘 할 수 있는 주제. 그리고 어떤 사람이 분석했느냐도 영향을 준다. 분석한 의도에 대해 설명할 수 있는 주제
# - 프로젝트를 진행할때 고려해야할 사항
#     - 데드라인 : 맞추라고 있는것! DSS의 데드라인은??? 하이어링데이임--> 결과가 나와있고 최고의 결과물이 나와있을 시기이다.
#     - 캐글데이터를 활용해도 좋다.
#     - 혼자하는 데이터분석이더라도 데드라인을 가지고 갈것.
#     - 알고리즘과 파라미터 선택의 근거를 항상 생각해라. ==> 파라미터세팅이 가장 중요하다. 그렇다면 왜 그랬는지가 중요하겠지??
#     - 코드는 구조화해서 사용하는것이 유익하다.(회사에서 당연히 구조화해서 사용하것지)
#     - 코드는 항상 의심하면서 보아야한다. 에러가 없다고 그게 맞는게 아닐 수 있다.
#     - README파일 정리하는것 중요하다. github주소를 요구하는 회사도 많으니 잘 정리할것
#
# #### - 전통 통계모형 vs 머신러닝의 차이점
# - 전통적 통계학습은 규칠을 알고 인풋을 넣는것임.
# - 머신러닝을 결과와 인풋으로 규칙을 찾는것임.
#
# #### 취업할때 고려해야하는것?
# - 동료와 성장가능성의 여부를 꼭 파악해라
# - 데이터팀이 있는 회사 + 규모가 좀 되는 회사
# - 회사에 대한 리서치
# - 포트폴리오 구성
# - 알고리즘 코딩
# - 학습데이터분석 지식 복습
#
# - 갖추면 좋은 것
#     - git
#     - Linux
#     - docker
#     - apache spark
#     - 그리고 좋은 프로젝트!
#     - kaggle 이런거에서 프로젝트 찾아서 해보거라
#
# ### 솔리드웨어
# - 머신러닝 분석 플랫폼을 개발하는 회사
# - 금융회사들에 솔루션 납품중
#
#
# #### 회사에서 하는일
# - 회사미팅시 요건정리
# - 데이터분석
# - AI모델개발
# - 시스템 인테그레이션
#
# ...
# - 고객이나 그걸 사용하는 사람 입장에서
# - 얼마나 효율성을 높일 수 있는가?
# - 얼마나 최적화를 할 수 있는가?
# - 이러한것들을 따지자.
