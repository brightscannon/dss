# %% [markdown]
# # 데이터 분석가 권정민(우아한형제들)
# - 데이터분석 13년차
# --------------
#
# ### 데이터 사이언티스트가 무슨일을 할까?
#
# - 아마 대부분이 생각했던것과 다를것이다.
#
# - 어떤 사람을 만나고, 어떤회사에 가고, 어떤 업계인가에 따라서 그때그때 다르다.
#
# - IT(카카오, 네이버), O2O(배민,쿠팡,G마켓)
#
# - 데이터에 대한 개념이 별로 없는 회사에 가서 고생하다 나오는 경우도 ㅜㅜ
#
# - 데이터 사이언스의 80%는 데이터 클리닝이다. 나머지 20%는 클리닝된 데이터의 컴플레이닝이다...
#     -->> 천국은 없는듯 ㅜㅜ
#
# - 주니어 뽑을때마다 마음이 안좋아진다 ㅜㅜ
#
#
# - 데이터 분석 환경 보기
#     - DB와 SQL은 매우 중요하다. 솔직히 어딜가도 쓴다.
#     - Hadoop, spark같은것도 쓰고
#     - R과 Python중 최소 하나는 한다.(무조건 둘중 하나는 하자)
#     - Tensorflow는 머~
#     - 물론 상황따라 회사따라 그때그때 다르다.
#
# - 회사면접같은거 할때 데이터에 대한 내용을 꼭 물어보는게 좋을것이다.
#
# - (신입) 데이터 분석가에게 기대하는것?
#     - 높은 수학능력 X, 뛰어난 코딩능력 X
#     - 인내심과 겸손함
#     - 업무와 학습에 대한 의지
#     - 기본적인 데이터 처리 능력
#
# - 어쩔수 없이 노가다는 필수다. 그래야 인사이트 얻기때문에....
#
# - 공부할것이 많다. 모든능력이 만렙일수는 없겠지만 적어도 현업에서 조금씩이라도 유용하게 사용되어야 할 것이다.
#
# - 새로운 분야에서 데이터 분석을 시작하게되기라도하는 날엔.... 그 분야 전반을 3주만에 다 공부해야될수도 있다. (개꾸르)
#
# - 기본적인 데이터 처리를 할줄 알아야 할 것.
# - R이나 Python은 잘써도 SQL을 못쓰는사람이 많아.. ㅜㅜ 잘 할 수 있어야 합니당.
#
#
# -
#
#
# # Q&A
#
# - 내 질문 : 1) 배민에서도 몽고DB와 같은 NoSQL류의 데이터베이스를 쓰는지? 쓴다면 어떤 용도로 주로 쓰는지?
#             2) 대기업화되어갈수록 효율성과 절차가 정교해져서 위기에 잘 대응하게 되지만. 그만큼 딱닥해지고 좀 자유도가 점점 줄어들수 밖에 없다고 생각합니다. 배민은 어디쯤 있다고 보십니까?
#             3) 자랑할만한점 있으신가요? 우리회사 이건 진짜 좋다. 이것때문에 안나갈것이다.
#             4)
#
# - 자력 능력, 학벌이 취업에 영향을 주는가요? : 이 부분은 보는사람마다 다를 수가 있다. 석사이상을 선호하기는 하는데... 왜 석사이상을 뽑는지를 1도 모르겠다. 현업에서 잘하는사람이 좋고, 공부를 많이 하시는 분들이 좋다.
#
#
# - 근무환경은? 하루일과는? : 데이터 클렌징과 데이터 클렌징... 그리고 데이터 없다고 다른데 가서 데이터 달라고 조르기 하거나 옥신각신하기 등등...
#
# - 신입사원이 오면 무엇을 먼저 시키나요? : 회사의 데이터 상태를 먼저 쫙 보여줍니다. 그리고, 분석할때 썼던 쿼리나 코드를 보게하고, 간단한 프로젝트, 정리안된 회사 데이터 정리 등등~ 물론 큰회사면 나눠서 진행시킬 수 있겠지만... 작은 회사는 아무래도 다같이 고생할듯하다.
#
# - 솔직히... 포트폴리오를 많이 보지는 않는다. 이력서를 자세하게 쓰면 크게 상관이 없는경우도... 이력서를 딱 포멧이 있는 경우는 좋을 수 있지만... 자세하게 보는 경우는 거의 없다. 그냥 원래 쓰려고 했던것만 좀 잘 쓸것. (내 생각엔 포트폴리오는 증거자료고 실제로 겪은일을 쓰는게 좋을듯 허이허이~~)
#
# - 어던 회사를 다니셨나요> : 여기저기... 음... 금융도 있었고, 도메인과, 데이터 분석종류는 조금씩 달라도 거의 하는일을 비슷하다. 환경다르고 쓰는 데이터 다르고 정도?? 회의시간이 길다 짧다> 길다 ㅜㅜ
#
# - 배민광고 : 우아한형제들 데이터 서비스팀이 존재함. 1년반정도됨. 회사 800명정도? 데이터 서비스팀의 규모는 크지 않다. 14명 정도다... 분석가는 5명밖에... 사람 부족함, 몽촌토성아니고 잠실이다.
# - 신입도 뽑고 다뽑고~~~ 지원해봐~
# - 이력서 넣으면 면접을 잘 보는편이다. 이력서 너무 잘써서 실제로 봤을때 실망하는 경우도 ㅜ. 이 회사는 임원면접이 너무너무 헬이다. 하여튼 어렵다고.. 그래서 안봅히는거 아닐까?
#
# - 딥러닝이나 등등... 이런거 쓰나요? : 실무에서 많이 쓰이지는 못하다. 이유는? 설명력이 좀 부족한 경우가 많아서야. 왜 그렇게 되는지를 설명 못하니까 쓰이지 못하는 경우가 ㅜ 검증하는 일도 쉽지가 않다.
#
# - 데이터 클렌징의 예좀 들어주세요 : 범주가 너무 넒은데? 일단 데이터가 정리가 안된경우가 허다함. 그냥 json에 문자열로 우수수~ 그걸 전처리 한다. 갑자기 데이터가 없는경우도 있고, 데이터가 안남은경우도 있고 ㅜㅜㅜ 컬럼 두개가 값이 잘못 들어간 휴먼에러도 있고... 어던 이벤트가 있어서 데이터가 튄 경우도 있고..
#
# - 도메인이 자주 다르신데.. 금융분야에 대한 도메인은 선택하셨는지? : 같은 도메인에서 일한경우가 별로 없다. 이것도 해봐야지 하면서 들어갔다가 고생고생하고 후반가서는 끝까지 해보자는 생각도 있고~
#
# - 내질문 1:  NoSQL 카산드라. 몽고DB - 간단한 검색에는 유용한데 조건이 많이 걸리고 그러면 힘들다. 그래서 보통 데이터를 쓸때 3가지로 구분한다. 거래내역을 쌓을때는 OLTP, OLEP 데이터를 많은 조건을 걸어버리는 것, 집계도. 아직까지는 NOSQL은 OLTP쪽 데이터는 잘되는데 조건걸리는데는 좀 불리하다. 데이터 분석용으로는 적합하지 않다고 본다.
#
# - 차라리 하둡이나 스파크 쓰는경우가 더 많을수도 있음
#
# - 손글씨 데이터....는 없는것보다는 나은거같다.
#
# - 의사결정을 하기 위해 마케팅팀에서 데이터를 의뢰하고 요청해도 활용 안되는경우도 많지 않은가?
#
# - 내질문 2 : 들어올때보다 인원이 2배가 됨.... 아직까지는 자율성이 높은 편이고, 스타트업다닐때
# - 사람이 많을때보다 예전이 더 딱딱했던 분위기였다.
#
# - 공고보니가 2년경력 묻는데지금? 주니어도 뽑는다면서? : 주니어라함은 5년이하다.........
# - 물론 그건 희망사항이고 2년 안되어도 붙여주는경우도 많아~ 일단 써보자.
#
# - 업무특성은 어떤가? : 전공은 다양하다. 예전부터 지금까지그렇다. 그러나아~ 산업공학과가 있으면 쪼끔 좋은듯??? 통계학과나온경우.... 파이썬배우느라 고생, 아예 CS하신분들은 데이터 잘못보거나 통계적인 지식에서의 문제가 생김. 심리학과출신이 은근히 있는편이다.
